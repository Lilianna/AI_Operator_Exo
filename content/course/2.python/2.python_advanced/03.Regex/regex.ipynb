# %% [markdown]
# # Regular expressions (regex) : love or hate?

# %% [markdown]
# ![commit strip](http://www.commitstrip.com/wp-content/uploads/2014/02/Strips-Le-dernier-des-vrais-codeurs-650-finalenglsih.jpg)

# %% [markdown]
# Regular expressions are used in almost all languages. It is a very powerful tool to check if the content of a variable has the shape you expect.
#
# For example, if you retrieve a phone number, you expect the variable to be composed of numbers and spaces (or dashes) but nothing more.
#
# Regular expressions not only warn you of an unwanted character but also delete/modify all those that are not desirable.

# %% [markdown]
# **There are two ways to use regular expressions:**
# * The first consists in calling the function with the pattern as the first parameter, and the string to be analyzed as the second parameter.
# * The second way is to compile the regex, and then use the methods of the created object to analyze a string passed as an argument. This method speeds up processing when a regex is used several times.

# %%
import re

# %%
pattern = "[ ]"
string = "I am fine ! There are still 6 months left :()"

# Searches the pattern in the previous string and return a `MatchObject` if matches are found,
# otherwise returns `None`.
print(re.search(pattern, string))
# Out:
# <re.Match object; span=(1, 2), match=' '>

# %%
pattern = "[ ]"
string = "I am fine ! There are still 6 months left :()"

# Cuts the string according to the occurrence of the pattern.
print(re.split(pattern, string))

# %% [markdown]
# ### A little syntax
#
#     [xy]  A possible segment list. Example[abc] equals: a, b or c
#
#     (x|y) Indicates a multiple choice type (ps|ump) equals "ps" OR "UMP"
#
#     \d    the segment is composed only of numbers, which is equivalent to [0-9].
#
#     \D    the segment is not composed of numbers, which is equivalent to [^0-9].
#
#     \s    A space, which is equivalent to [ \t\n\r\r\f\v].
#
#     \S    No space, which is equivalent to [^ \t\n\r\f\v].
#
#     \w    Alphanumeric presence, which is equivalent to [a-zA-Z0-9_].
#
#     \W    No alphanumeric presence [^a-zA-Z0-9_].
#
#     \     Is an escape character. It _unprotects_ reserved characters by restoring their original meaning.

# %% [markdown]
# ### Let's try it.
#
# If the answer is not `None`, it means the match matches. GREY is indeed a name beginning with GR followed by a character and ending with Y.

# %%
print(re.match("GR(.)?Y", "GREY"))
# (.)? means that we expect 0 or 1 character.
# 0 or 1 because of the `?` following the character `.`, which means any character

# %%
pattern = "GR(.)?Y"
string = "GREY"

result = re.match(pattern, string)
print(result)

# It is equal to
compiled = re.compile(pattern)
result = compiled.match(string)
print(result)
# Out:
# <re.Match object; span=(0, 4), match='GREY'>
# <re.Match object; span=(0, 4), match='GREY'>

# %%
#  So in a loop the second syntax is nicer
pattern = "GR(.)?Y"
compiled = re.compile(pattern)
l = ["GREY 'S", "GRAY", "GREYISH", "A GREY"]

for elem in l:
    result = compiled.match(elem)
    print(elem, result)
# Out:
# GREY 'S <re.Match object; span=(0, 4), match='GREY'>
# GRAY <re.Match object; span=(0, 4), match='GRAY'>
# GREYISH <re.Match object; span=(0, 4), match='GREY'>
# A GREY None

# %% [markdown]
# In the following, we search for specific expressions in a string.

# %%
print(re.findall("GR(.)?Y", "GREY"))
# so here we are looking for a unique element (.)? between GR and Y
# Out:
# ['E']

# %%
# Ditto for two characters to be found
re.findall("G(.)?(.)?Y", "GREY")
# Out:
# [('R', 'E')]

# %% [markdown]
# To keep only numbers.

# %%
# Only numbers
print(re.findall("([0-9]+)", "Hello I live on the 7th floor of 220 street of sims"))
# "+" Means 1 or more characters
# Out:
# ['7', '220']

# %% [markdown]
# And conversely, if you only want to keep the words.

# %%
# Only words
print(re.findall("([A-z]+)", "Hello I live on the 7th floor of 220 street of sims"))
# Out:
# ['Hello', 'I', 'live', 'on', 'the', 'th', 'floor', 'of', 'street', 'of', 'sims']

# %% [markdown]
# ### Stop, we recap !

# %% [markdown]
# Character | Meaning
# :-------------------------:|:-------------------------:
# **.** | Refers to any character.
# **^** | Indicates the beginning of the string.<br />For example, _^a_ matches _ab_ but not _ba_.
# **$** | Indicates the end of the string.<br />For example, _a$_ matches _ba_ but not _ab_.
# **?**| The previous character can be repeated zero or once.<br /> For example, _ab?_ corresponds to _ab_ and _a_.
#  *| The previous character can be repeated none or several times. <br />For example, _ab\*_ may correspond to: _a_, _ab_, or _a_ followed by any number of _b_.
# **+**| The previous character can be repeated once or several times. <br/>For example, to _ab+_ corresponds an _a_ followed by any number of _b_.
# **{n}**| Indicates that the previous character must be repeated _n_ times.
# **{n, m}**|Indicates that the previous character must be repeated between _n_ and _m_ times.
# **\w** | It corresponds to any alphabetical character, it is equivalent to _[a-zA-Z]_.
# **\W** | It corresponds to everything that is not an alphabetical character.
# **\d** | It corresponds to any numeric character, i.e. it is equivalent to _[0-9]_.
# **\D** | It corresponds to everything that is not a numeric character.

# %% [markdown]
# <img src="https://i.redd.it/nac35ntlfg831.jpg" width="400">

# %% [markdown]
# ### Some useful resources
# [Regex quickstart](http://www.rexegg.com/regex-quickstart.html): the Regex cheat sheet
#
# [Dreambank Regex](http://www.dreambank.net/regex.html#examples): some examples of regex behaviour
#
# [Pythex](https://pythex.org/): a real-time regular expression editor for Python, a quick way to test your regular expressions.
#
# [Regex101](https://regex101.com/): online regex editor and debugger. Regex101 allows you to create, debug, test and have your expressions explained for PHP, PCRE, Python, Golang and JavaScript. The website also features a community where you can share useful expressions.
#
# ##### And just for fun...
# [Regex Crosswords](https://regexcrossword.com/): some crossword puzzles to test your Regex knowledge

# %% [markdown]
# #### How to check that the entered string is that of a number ?

# %%
import re
number = input("Your number : ")
if re.match("^[0-9]+$", number):
    print("The string entered is a number.")
else:
    print("The string entered is NOT a number.")

# %% [markdown]
# Another way

# %%
compiled = re.compile("^[0-9]+$")
if compiled.search(number) is not None:
    print("The string entered is a number.")
else:
    print("The string entered is NOT a number")
# Out:
# The string entered is NOT a number

# %% [markdown]
# ### Drill

# %% [markdown]
# **1. Create a regex that finds integers without size limit.**

# %%
import re
complied = re.compile("^\d+$")

s = "sssgdds8sfsfs"
if complied.search(s) is not None:
    print(f"The string {s} is an integer")
else:
    print(f"The string {s} is not an integer")
# Out:
# The string sssgdds8sfsfs is not an integer

# %% [markdown]
# **2. Create a regex that finds negative integers without size limit.**

# %%
import re
complied = re.compile("^-\d+$")

s = "sssgdds8sfsfs"
if complied.search(s) is not None:
    print(f"The string {s} is a negative integer")
else:
    print(f"The string {s} is not a negative integer")
# Out:
# The string sssgdds8sfsfs is not a negative integer

# %% [markdown]
# **3. Create a regex that finds (positive or negative) integers without size limit.**

# %%
import re
complied = re.compile("^-?\d+$")

s = "sssgdds8sfsfs"
if complied.search(s) is not None:
    print(f"The string {s} is an integer")
else:
    print(f"The string {s} is not an integer")
# Out:
# The string sssgdds8sfsfs is not an integer

# %% [markdown]
# **4. Capture all the numbers of the following sentence :**

# %%
import re

compiled = re.compile(r"[0-9]+")

text = "21 scouts and 3 tanks fought against 4,003 protestors, so the manager was not 100.00% happy."
numbers_in_string = compiled.findall(text)

if numbers_in_string:
    print(f"The string \"{text}\" contains numbers: {numbers_in_string}")
else:
    print(f"The string \"{text}\" does not contain any numbers.")

print(f"{numbers_in_string} is {type(numbers_in_string)}")
# Out:
# The string "21 scouts and 3 tanks fought against 4,003 protestors, so the manager was not 100.00% happy." contains numbers: ['21', '3', '4', '003', '100', '00']
# ['21', '3', '4', '003', '100', '00'] is <class 'list'>

# %% [markdown]
# **5. Find all words that end with 'ly'.**

# %%
import re

compiled = re.compile(r'\w+ly\b')  # Words ending with "ly" 
#\w+ matches one or more word characters (letters and digits)
# \b is a word boundary assertion to ensure that "ly" is at the end of the word.

text = "He had prudently disguised himself but was quickly captured by the police."
words_ending_with_ly = compiled.findall(text)

if words_ending_with_ly:
    print(f"The string \"{text}\" contains words ending with 'ly': {words_ending_with_ly}")
else:
    print(f"The string \"{text}\" does not contain any such word.")

print(f"{words_ending_with_ly} is {type(words_ending_with_ly)}")
# Out:
# The string "He had prudently disguised himself but was quickly captured by the police." contains words ending with 'ly': ['prudently', 'quickly']
# ['prudently', 'quickly'] is <class 'list'>

# %% [markdown]
# **6. License plate number**
# A Belgian license plate consists of 1 digit (0, 1 or 2), a dash ('-'), 3 capital letters, a dash ('-') and finally 3 digits. Write a script to check that an input string is a valid license plate.
# If it's correct, print `"good"`. If it's not correct, print `"Not good"`.

# %%
import re

pattern = r'^[012]-[A-Z]{3}-\d{3}$'

compiled = re.compile(pattern) 
plate = input("Enter your license plate number: ")

check_plate = compiled.match(plate)
if check_plate:
    print(f"{plate} is valid lisence")
else:
    print(f"{plate} is invalid lisence")

print(f"{check_plate} is {type(check_plate)}")
# Out:
# 2-BUD-234 is valid lisence
# <re.Match object; span=(0, 9), match='2-BUD-234'> is <class 're.Match'>

# %% [markdown]
# **7. Address IPV4**
# An IPv4 address is composed of 4 numbers between 0 and 255 separated by '.'
# Write a script to verify that a string entered is a valid IPv4 address.

# %%
import re

pattern = r'^(\d{1,3}\.){3}\d{1,3}$'

compiled = re.compile(pattern)

ip = input("Enter your IP address: ")

check_ip = compiled.match(ip)

if check_ip:
    # Further validation to check if each octet is within the valid range (0-255)
    octets = ip.split('.')
    valid_ip = all(0 <= int(octet) <= 255 for octet in octets)
    if valid_ip:
        print(f"{ip} is a valid IP address.")
    else:
        print(f"{ip} is not a valid IP address (out of range).")
else:
    print(f"{ip} is not a valid IP address (invalid format).")
    

print(f"{valid_ip} is {type(valid_ip)}")
# Out:
# 234.123.8.234 is a valid IP address.
# True is <class 'bool'>

# %% [markdown]
# **8. Valid Mail**
# An email is composed of alphanumeric characters followed by `@` and a domain name.
# Write a script that checks that the string entered by a user is indeed that of an email, otherwise ask him to re-enter it again (until he gets a valid email).

# %%
import re

# Function: is_valid_email
# Validates an email address using a regular expression pattern.
# Parameters:
#   - email (str): The email address to be validated.
# Returns:
#   - bool: True if valid, False otherwise.
def is_valid_email(email):
    pattern = r'^[a-zA-Z0-9]+@[a-zA-Z0-9.-]+\.[a-zA-Z]{2,}$'
    return re.match(pattern, email)

email = input("Enter an email address: ")

if is_valid_email(email):
    print(f"{email} is a valid email address.")
else:
    print(f"{email} is not a valid email address.")
# Out:
# nguyen@hoa.com is a valid email address.

# %% [markdown]
# **9. Valid Password**
# Write an additional script that verifies the password (obviously if the email is valid) where the only specificity of the password is that it has to contain at least 6 characters.

# %%
import re

# Function: is_valid_email
# Description: Validates an email address using a regular expression pattern.
# Parameters:
#   - email (str): The email address to be validated.
# Returns:
#   - bool: True if valid, False otherwise.
def is_valid_email(email):
    # Define the regular expression pattern for a valid email address
    pattern = r'^[a-zA-Z0-9]+@[a-zA-Z0-9.-]+\.[a-zA-Z]{2,}$'

    # Use re.match() to check if the input email matches the pattern
    return re.match(pattern, email)

# Function: is_valid_password
# Description: Validates a password: any character, len >=6.
# Parameters:
#   - password (str): The password to be validated.
# Returns:
#   - bool: True if valid, False otherwise.
def is_valid_password(password):
    # Password validation requiring a minimum length of 6 characters:
    return len(password) >= 6

# Get an email address and password from the user
email = input("Enter an email address: ")
password = input("Enter a password: ")

# Check if the input email is valid
if is_valid_email(email):
    print(f"{email} is a valid email address.")
else:
    print(f"{email} is not a valid email address.")

# Check if the input password is valid
if is_valid_password(password):
    print("Password is valid.")
else:
    print("Password is not valid. It should be at least 6 characters long.")
# Out:
# hoa@nguyen.com is a valid email address.
# Password is valid.

# %% [markdown]
# **10. Valid Password bis**
# The password must now contain at least 6 characters AND
#
# - at least one lowercase letter AND
# - at least one uppercase letter AND
# - at least one number AND
# - at least one special character (among `$#@`).

# %%
import re

# Function to validate an email address letters, then @, then domain name
def is_valid_email(email):
    pattern = r'^[a-zA-Z0-9]+@[a-zA-Z0-9.-]+\.[a-zA-Z]{2,}$'
    return re.match(pattern, email)

# Function to validate a password
import re

def is_valid_password(password):
    # Password validation requiring a minimum length of 6 characters
    # and AT LEAST: one uppercase, one lowercase, one number, one special character [@, $, !, %, *, ?, &]
    pattern = r'^(?=.*[a-z])(?=.*[A-Z])(?=.*\d)(?=.*[@$!%*?&])[A-Za-z\d@$!%*?&]+$'
    
    return bool(re.match(pattern, password)) and len(password) >= 6


# Get an email address from the user
#email = input("Enter an email address: ")
email = "abc123@hotmail.org"

# Check if the input email is valid
if is_valid_email(email):
    print(f"Email address {email} is valid.")
    
    # If the email is valid, get the password from the user
    #password = input("Enter a password: ") 
    password = "Passw01@"

    # Check if the input password is valid
    if is_valid_password(password):
        print(f"Password {password} is valid.")
    else:
        print("Password is not valid. It should be at least 6 characters long, and at least: one lowercase, one uppercase, one number and one special character  [@, $, !, %, *, ?, &].")
    
    # Test the function of validating password: 
    password2 = "weak"
    password3 = "TooShort1"
    print(is_valid_password(password2))  #  return False
    print(is_valid_password(password3))  # return False
# Out:
# Email address abc123@hotmail.org is valid.
# Password Passw01@ is valid.
# False
# False

# %% [markdown]
# **11. Search by groups**
# It is possible to search by groups, and it is very powerful!
# `?P<x>\w+` means the capture of a "group" named `x`, this group is composed of at least (`+`) one alphanumeric  character `(\w)`.

# %%
m = re.search(
    "Welcome to (?P<where>\w+) ! You are (?P<age>\d+) years old ?",
    "Welcome to Olivier ! You are 32 years old ?",
)
print(m.group("where"))
print(m.group("age"))
# Out:
# Olivier
# 32

# %%
# Another Example
m = re.search(
    "^(?P<who>\w*)[.]?(?P<who2>\w*)@(?P<operator>\w+)[.](?P<zone>\w+$)",
    "audrey.boulevart@benextcomapgny.com",
)
if m is not None:
    print(m.group("who"))
    print(m.group("who2"))
    print(m.group("operator"))
    print(m.group("zone"))
# Out:
# audrey
# boulevart
# benextcomapgny
# com

# %% [markdown]
# Load the file `./data/mail.txt` and clean it with the regex. The goal is to retrieve the last name, first name, operator and zone, as in the previous example. Store each of those into their own separate list.

# %%
#  Reads the contents of the mail.txt file into the list_mail list, and then 
#  it processes each email address from that list using the regex pattern and 
#  stores the extracted information in separate lists as before.

import re

# Initialize lists to store extracted information
first_names = []
last_names = []
operators = []
zones = []

# Define the regex pattern
pattern = r"^(?P<who>\w*)[.]?(?P<who2>\w*)@(?P<operator>\w+)[.](?P<zone>\w+$)"

# Read the contents of the 'mail.txt' file into a list
with open('./data/mail.txt', 'r') as file:
    list_mail = file.readlines()

# Iterate through the list of email addresses
for line in list_mail:
    # Use regex to extract information from each email address
    m = re.search(pattern, line)
    
    if m is not None:
        # Append extracted information to respective lists
        # extract specific parts of the email address using m.group() when a match is found.
        first_names.append(m.group("who"))
        last_names.append(m.group("who2"))
        operators.append(m.group("operator"))
        zones.append(m.group("zone"))

# Print the extracted information
for i in range(len(first_names)):
    print("First Name:", first_names[i])
    print("Last Name:", last_names[i])
    print("Operator:", operators[i])
    print("Zone:", zones[i])
    print()  # Add an empty line for separation if needed
# Out:
# First Name: aikin
# Last Name: joe
# Operator: odul
# Zone: xyz
#
# First Name: moore
# Last Name:
# Operator: imail
# Zone: gov
#
# First Name: halknutson
# Last Name:
# Operator: email
# Zone: xyz
#
# First Name: alexnorquist
# Last Name:
# Operator: proton
# Zone: com
#
# First Name: monte
# Last Name: hylan
# Operator: belgaximus
# Zone: net
#
# First Name: knutsondan
# Last Name:
# Operator: belgaximus
# Zone: org
#
# First Name: lepage
# Last Name:
# Operator: gaagle
# Zone: xyz
#
# First Name: chapman_ben
# Last Name:
# Operator: napster
# Zone: hu
#
# First Name: upson1544
# Last Name:
# Operator: youhoo
# Zone: hu
#
# First Name: 552966959
# Last Name:
# Operator: belgaximus
# Zone: hu
#
# First Name: soloman_ziegler
# Last Name:
# Operator: email
# Zone: tech
#
# First Name: ortiz
# Last Name: mark
# Operator: napster
# Zone: me
#
# First Name: ashwoon_hank
# Last Name:
# Operator: imail
# Zone: io
#
# First Name: pettigrew
# Last Name:
# Operator: proton
# Zone: hu
#
# First Name: doranedward
# Last Name:
# Operator: napster
# Zone: net
#
# First Name: mills_joe
# Last Name:
# Operator: imail
# Zone: xyz
#
# First Name: yang
# Last Name:
# Operator: email
# Zone: hu
#
# First Name: ike
# Last Name:
# Operator: ecoin
# Zone: io
#
# First Name: larrytrebil
# Last Name:
# Operator: email
# Zone: org
#
# First Name: davis_ike
# Last Name:
# Operator: odul
# Zone: io
#
# First Name: davidsonhal
# Last Name:
# Operator: hotmoille
# Zone: apple
#
# First Name: john8733
# Last Name:
# Operator: youhoo
# Zone: com
#
# First Name: johnfletcher
# Last Name:
# Operator: youhoo
# Zone: me
#
# First Name: cataldi_larry
# Last Name:
# Operator: napster
# Zone: com
#
# First Name: rogerfietzer
# Last Name:
# Operator: imail
# Zone: apple
#
# First Name: edward4185
# Last Name:
# Operator: gaagle
# Zone: gov
#
# First Name: hancock_matthew
# Last Name:
# Operator: belgaximus
# Zone: gov
#
# First Name: solberg_cast
# Last Name:
# Operator: gaagle
# Zone: apple
#
# First Name: georgepak
# Last Name:
# Operator: gaagle
# Zone: me
#
# First Name: ike
# Last Name:
# Operator: ecoin
# Zone: com
#
# First Name: tapia_quinn
# Last Name:
# Operator: gaagle
# Zone: io
#
# First Name: 795419860
# Last Name:
# Operator: imail
# Zone: tech
#
# First Name: jack
# Last Name:
# Operator: gaagle
# Zone: apple
#
# First Name: joe
# Last Name:
# Operator: ecoin
# Zone: tech
#
# First Name: ben
# Last Name: yang
# Operator: ecoin
# Zone: com
#
# First Name: pettigrewgeorge
# Last Name:
# Operator: odul
# Zone: me
#
# First Name: boyd_carl
# Last Name:
# Operator: napster
# Zone: me
#
# First Name: yocum_mark
# Last Name:
# Operator: youhoo
# Zone: com
#
# First Name: george59
# Last Name:
# Operator: ecoin
# Zone: gov
#
# First Name: johnsen2201
# Last Name:
# Operator: imail
# Zone: io
#
# First Name: schutzlarry
# Last Name:
# Operator: email
# Zone: apple
#
# First Name: quizoz
# Last Name: joe
# Operator: napster
# Zone: tech
#
# First Name: matthew8227
# Last Name:
# Operator: hotmoille
# Zone: me
#
# First Name: georgemoody
# Last Name:
# Operator: hotmoille
# Zone: com
#
# First Name: lawicki589
# Last Name:
# Operator: hotmoille
# Zone: me
#
# First Name: doran7947
# Last Name:
# Operator: gaagle
# Zone: tech
#
# First Name: mark
# Last Name:
# Operator: email
# Zone: io
#
# First Name: waltermartin
# Last Name:
# Operator: ecoin
# Zone: gov
#
# First Name: george
# Last Name:
# Operator: hotmoille
# Zone: hu
#
# First Name: ferry
# Last Name: victor
# Operator: gaagle
# Zone: com
#
# First Name: fred
# Last Name: weiss
# Operator: odul
# Zone: tech
#
# First Name: jurgensonpeter
# Last Name:
# Operator: proton
# Zone: tech
#
# First Name: stevefietzer
# Last Name:
# Operator: ecoin
# Zone: tech
#
# First Name: sonderling_caswell
# Last Name:
# Operator: napster
# Zone: tech
#
# First Name: johnsen
# Last Name: walter
# Operator: odul
# Zone: net
#
# First Name: mccormack
# Last Name:
# Operator: napster
# Zone: xyz
#
# First Name: roberts
# Last Name: hank
# Operator: proton
# Zone: net
#
# First Name: valente
# Last Name:
# Operator: gaagle
# Zone: xyz
#
# First Name: ory_walter
# Last Name:
# Operator: proton
# Zone: hu
#
# First Name: tyirwin
# Last Name:
# Operator: proton
# Zone: tech
#
# First Name: paulferry
# Last Name:
# Operator: hotmoille
# Zone: com
#
# First Name: george
# Last Name:
# Operator: youhoo
# Zone: gov
#
# First Name: mccormack
# Last Name: carl
# Operator: imail
# Zone: xyz
#
# First Name: 851886792
# Last Name:
# Operator: youhoo
# Zone: hu
#
# First Name: zeaser_aaron
# Last Name:
# Operator: belgaximus
# Zone: apple
#
# First Name: adam
# Last Name:
# Operator: proton
# Zone: net
#
# First Name: tisler
# Last Name: roger
# Operator: hotmoille
# Zone: tech
#
# First Name: severson_george
# Last Name:
# Operator: proton
# Zone: org
#
# First Name: otto
# Last Name: nuttle
# Operator: proton
# Zone: hu
#
# First Name: illingsworth
# Last Name:
# Operator: belgaximus
# Zone: gov
#
# First Name: alex685
# Last Name:
# Operator: hotmoille
# Zone: com
#
# First Name: hancock_valente
# Last Name:
# Operator: hotmoille
# Zone: net
#
# First Name: paul9581
# Last Name:
# Operator: email
# Zone: tech
#
# First Name: sawyer_chambers
# Last Name:
# Operator: belgaximus
# Zone: xyz
#
# First Name: johnsen
# Last Name: tim
# Operator: email
# Zone: gov
#
# First Name: aaron
# Last Name: roberts
# Operator: imail
# Zone: gov
#
# First Name: schiebel2392
# Last Name:
# Operator: hotmoille
# Zone: xyz
#
# First Name: mccormackedward
# Last Name:
# Operator: proton
# Zone: com
#
# First Name: tapia1876
# Last Name:
# Operator: imail
# Zone: tech
#
# First Name: quizoz9628
# Last Name:
# Operator: belgaximus
# Zone: apple
#
# First Name: rogerstahl
# Last Name:
# Operator: odul
# Zone: apple
#
# First Name: schutz_johnsen
# Last Name:
# Operator: ecoin
# Zone: tech
#
# First Name: carlupson
# Last Name:
# Operator: napster
# Zone: me
#
# First Name: larry349
# Last Name:
# Operator: odul
# Zone: me
#
# First Name: matthew
# Last Name: linde
# Operator: youhoo
# Zone: tech
#
# First Name: mcginnis
# Last Name:
# Operator: imail
# Zone: xyz
#
# First Name: nugent_jack
# Last Name:
# Operator: gaagle
# Zone: hu
#
# First Name: wagle_john
# Last Name:
# Operator: napster
# Zone: gov
#
# First Name: chapmannathan
# Last Name:
# Operator: youhoo
# Zone: org
#
# First Name: hal536
# Last Name:
# Operator: napster
# Zone: net
#
# First Name: 472510707
# Last Name:
# Operator: odul
# Zone: io
#
# First Name: thomas
# Last Name: casal
# Operator: hotmoille
# Zone: com
#
# First Name: adamillingsworth
# Last Name:
# Operator: youhoo
# Zone: xyz
#
# First Name: peterstahl
# Last Name:
# Operator: gaagle
# Zone: me
#
# First Name: victortandy
# Last Name:
# Operator: youhoo
# Zone: hu
#
# First Name: adam
# Last Name: sellon
# Operator: email
# Zone: tech
#
# First Name: ike3831
# Last Name:
# Operator: proton
# Zone: apple
#
# First Name: timfletcher
# Last Name:
# Operator: imail
# Zone: xyz
#
# First Name: frank
# Last Name: schickowski
# Operator: gaagle
# Zone: io
#
# First Name: 566486749
# Last Name:
# Operator: email
# Zone: net
#
# First Name: 675340599
# Last Name:
# Operator: proton
# Zone: org
#
# First Name: davis_nathan
# Last Name:
# Operator: ecoin
# Zone: com
#
# First Name: 253159777
# Last Name:
# Operator: gaagle
# Zone: net
#
# First Name: edwardschutz
# Last Name:
# Operator: hotmoille
# Zone: net
#
# First Name: sagar_carl
# Last Name:
# Operator: hotmoille
# Zone: org
#
# First Name: 331837931
# Last Name:
# Operator: napster
# Zone: me
#
# First Name: aaronbongard
# Last Name:
# Operator: odul
# Zone: xyz
#
# First Name: ty9516
# Last Name:
# Operator: belgaximus
# Zone: net
#
# First Name: schustersteve
# Last Name:
# Operator: proton
# Zone: tech
#
# First Name: moody_schiebel
# Last Name:
# Operator: hotmoille
# Zone: me
#
# First Name: soloman_ramachandran
# Last Name:
# Operator: gaagle
# Zone: org
#
# First Name: victor630
# Last Name:
# Operator: hotmoille
# Zone: hu
#
# First Name: yang_trebil
# Last Name:
# Operator: imail
# Zone: me
#
# First Name: hoffman_zeller
# Last Name:
# Operator: imail
# Zone: me
#
# First Name: ripka_thomas
# Last Name:
# Operator: email
# Zone: tech
#
# First Name: vader
# Last Name: hal
# Operator: belgaximus
# Zone: org
#
# First Name: ottochambers
# Last Name:
# Operator: imail
# Zone: io
#
# First Name: tylulloff
# Last Name:
# Operator: email
# Zone: gov
#
# First Name: 263935905
# Last Name:
# Operator: youhoo
# Zone: tech
#
# First Name: carlvail
# Last Name:
# Operator: napster
# Zone: me
#
# First Name: hanktisler
# Last Name:
# Operator: ecoin
# Zone: com
#
# First Name: uddin1510
# Last Name:
# Operator: email
# Zone: org
#
# First Name: mccormack
# Last Name: carl
# Operator: proton
# Zone: net
#
# First Name: vader
# Last Name:
# Operator: proton
# Zone: me
#
# First Name: nelsonmark
# Last Name:
# Operator: imail
# Zone: xyz
#
# First Name: stahl
# Last Name:
# Operator: odul
# Zone: apple
#
# First Name: timirwin
# Last Name:
# Operator: hotmoille
# Zone: me
#
# First Name: davis9134
# Last Name:
# Operator: imail
# Zone: tech
#
# First Name: davidziegler
# Last Name:
# Operator: imail
# Zone: tech
#
# First Name: carl1959
# Last Name:
# Operator: youhoo
# Zone: apple
#
# First Name: alexkeller
# Last Name:
# Operator: gaagle
# Zone: com
#
# First Name: 469322116
# Last Name:
# Operator: hotmoille
# Zone: tech
#
# First Name: monte7207
# Last Name:
# Operator: gaagle
# Zone: hu
#
# First Name: fredtiernan
# Last Name:
# Operator: email
# Zone: net
#
# First Name: fietzer
# Last Name:
# Operator: gaagle
# Zone: org
#
# First Name: benquinn
# Last Name:
# Operator: proton
# Zone: com
#
# First Name: hal
# Last Name: weiss
# Operator: email
# Zone: xyz
#
# First Name: sweeney
# Last Name: otto
# Operator: gaagle
# Zone: apple
#
# First Name: fletcher_monte
# Last Name:
# Operator: email
# Zone: com
#
# First Name: woothomas
# Last Name:
# Operator: napster
# Zone: tech
#
# First Name: walter
# Last Name:
# Operator: napster
# Zone: io
#
# First Name: dinkins
# Last Name:
# Operator: proton
# Zone: gov
#
# First Name: 950099319
# Last Name:
# Operator: imail
# Zone: net
#
# First Name: roger
# Last Name: myers
# Operator: gaagle
# Zone: io
#
# First Name: tim
# Last Name: trusela
# Operator: hotmoille
# Zone: gov
#
# First Name: sawyer
# Last Name: adam
# Operator: belgaximus
# Zone: org
#
# First Name: ben
# Last Name: jagtap
# Operator: napster
# Zone: tech
#
# First Name: carlmills
# Last Name:
# Operator: ecoin
# Zone: me
#
# First Name: markboyd
# Last Name:
# Operator: belgaximus
# Zone: apple
#
# First Name: 887934540
# Last Name:
# Operator: email
# Zone: net
#
# First Name: ortizjack
# Last Name:
# Operator: gaagle
# Zone: gov
#
# First Name: roberts_myers
# Last Name:
# Operator: email
# Zone: tech
#
# First Name: soloman8370
# Last Name:
# Operator: odul
# Zone: gov
#
# First Name: alex3716
# Last Name:
# Operator: ecoin
# Zone: me
#
# First Name: tim
# Last Name:
# Operator: proton
# Zone: me
#
# First Name: thompson85
# Last Name:
# Operator: proton
# Zone: hu
#
# First Name: reyes
# Last Name: jack
# Operator: email
# Zone: hu
#
# First Name: dinkinsroger
# Last Name:
# Operator: youhoo
# Zone: apple
#
# First Name: mills9634
# Last Name:
# Operator: odul
# Zone: xyz
#
# First Name: 821464747
# Last Name:
# Operator: odul
# Zone: gov
#
# First Name: valente_hydinger
# Last Name:
# Operator: hotmoille
# Zone: tech
#
# First Name: schiebel1467
# Last Name:
# Operator: proton
# Zone: io
#
# First Name: larryschiebel
# Last Name:
# Operator: ecoin
# Zone: net
#
# First Name: jagtap
# Last Name: fred
# Operator: proton
# Zone: gov
#
# First Name: edward
# Last Name: haworth
# Operator: imail
# Zone: com
#
# First Name: matthewcataldi
# Last Name:
# Operator: youhoo
# Zone: net
#
# First Name: zeller
# Last Name:
# Operator: email
# Zone: org
#
# First Name: duffman
# Last Name:
# Operator: email
# Zone: net
#
# First Name: ottoortiz
# Last Name:
# Operator: youhoo
# Zone: xyz
#
# First Name: delorenzo
# Last Name:
# Operator: ecoin
# Zone: me
#
# First Name: miller_keller
# Last Name:
# Operator: email
# Zone: org
#
# First Name: illingsworth
# Last Name:
# Operator: youhoo
# Zone: gov
#
# First Name: nelson
# Last Name:
# Operator: odul
# Zone: tech
#
# First Name: rogers_john
# Last Name:
# Operator: gaagle
# Zone: tech
#
# First Name: tyresnick
# Last Name:
# Operator: imail
# Zone: io
#
# First Name: hal
# Last Name: yang
# Operator: napster
# Zone: xyz
#
# First Name: tiernan6950
# Last Name:
# Operator: belgaximus
# Zone: tech
#
# First Name: mills
# Last Name:
# Operator: belgaximus
# Zone: xyz
#
# First Name: casal
# Last Name: hank
# Operator: proton
# Zone: xyz
#
# First Name: hankupson
# Last Name:
# Operator: odul
# Zone: xyz
#
# First Name: irwin_yang
# Last Name:
# Operator: gaagle
# Zone: gov
#
# First Name: napier
# Last Name: aaron
# Operator: email
# Zone: org
#
# First Name: edward
# Last Name: schickowski
# Operator: youhoo
# Zone: xyz
#
# First Name: rogers_lawicki
# Last Name:
# Operator: gaagle
# Zone: apple
#
# First Name: tapia_upson
# Last Name:
# Operator: ecoin
# Zone: me
#
# First Name: uddin_yocum
# Last Name:
# Operator: gaagle
# Zone: hu
#
# First Name: bongardroger
# Last Name:
# Operator: napster
# Zone: net
#
# First Name: victor
# Last Name:
# Operator: youhoo
# Zone: gov
#
# First Name: ty
# Last Name: schwager
# Operator: napster
# Zone: io
#
# First Name: paultiernan
# Last Name:
# Operator: youhoo
# Zone: xyz
#
# First Name: roger836
# Last Name:
# Operator: gaagle
# Zone: tech
#
# First Name: pettigrew
# Last Name: victor
# Operator: email
# Zone: io
#
# First Name: johnsen4863
# Last Name:
# Operator: gaagle
# Zone: apple
#
# First Name: 890280316
# Last Name:
# Operator: ecoin
# Zone: me
#
# First Name: weinstein
# Last Name: roger
# Operator: imail
# Zone: io
#
# First Name: alexschmitt
# Last Name:
# Operator: odul
# Zone: org
#
# First Name: dan
# Last Name: uddin
# Operator: ecoin
# Zone: apple
#
# First Name: steve
# Last Name: stahl
# Operator: hotmoille
# Zone: me
#
# First Name: matthewfrick
# Last Name:
# Operator: hotmoille
# Zone: com
#
# First Name: 237336989
# Last Name:
# Operator: email
# Zone: io
#
# First Name: larry6016
# Last Name:
# Operator: youhoo
# Zone: org
#
# First Name: otto5489
# Last Name:
# Operator: gaagle
# Zone: tech
#
# First Name: bongard_ty
# Last Name:
# Operator: ecoin
# Zone: xyz
#
# First Name: 169102677
# Last Name:
# Operator: gaagle
# Zone: me
#
# First Name: upson
# Last Name: hal
# Operator: gaagle
# Zone: io
#
# First Name: hal
# Last Name:
# Operator: hotmoille
# Zone: gov
#
# First Name: sonderling_mark
# Last Name:
# Operator: belgaximus
# Zone: me
#
# First Name: 430581778
# Last Name:
# Operator: hotmoille
# Zone: com
#
# First Name: walterkassing
# Last Name:
# Operator: napster
# Zone: tech
#
# First Name: victorceledon
# Last Name:
# Operator: ecoin
# Zone: xyz
#
# First Name: kassing
# Last Name:
# Operator: hotmoille
# Zone: apple
#
# First Name: duffman6005
# Last Name:
# Operator: youhoo
# Zone: hu
#
# First Name: frank
# Last Name: ventotla
# Operator: belgaximus
# Zone: io
#
# First Name: uddinotto
# Last Name:
# Operator: youhoo
# Zone: org
#
# First Name: 703979481
# Last Name:
# Operator: ecoin
# Zone: apple
#
# First Name: paul
# Last Name: nugent
# Operator: ecoin
# Zone: apple
#
# First Name: nugent
# Last Name:
# Operator: proton
# Zone: org
#
# First Name: alex
# Last Name:
# Operator: odul
# Zone: tech
#
# First Name: aaronsweeney
# Last Name:
# Operator: ecoin
# Zone: apple
#
# First Name: knutson_celedon
# Last Name:
# Operator: hotmoille
# Zone: xyz
#
# First Name: tydoran
# Last Name:
# Operator: belgaximus
# Zone: org
#
# First Name: millerhal
# Last Name:
# Operator: hotmoille
# Zone: org
#
# First Name: adamnuttle
# Last Name:
# Operator: youhoo
# Zone: hu
#
# First Name: ashwoon8609
# Last Name:
# Operator: youhoo
# Zone: tech
#
# First Name: mcginnis_reardon
# Last Name:
# Operator: youhoo
# Zone: org
#
# First Name: ramachandran
# Last Name: mark
# Operator: proton
# Zone: com
#
# First Name: monteshaffer
# Last Name:
# Operator: proton
# Zone: tech
#
# First Name: monte
# Last Name:
# Operator: proton
# Zone: gov
#
# First Name: pettigrew9750
# Last Name:
# Operator: proton
# Zone: com
#
# First Name: yocum_dan
# Last Name:
# Operator: napster
# Zone: xyz
#
# First Name: darnell8483
# Last Name:
# Operator: email
# Zone: xyz
#
# First Name: pettigrewlarry
# Last Name:
# Operator: imail
# Zone: tech
#
# First Name: ben5039
# Last Name:
# Operator: hotmoille
# Zone: tech
#
# First Name: mcginnis
# Last Name: dan
# Operator: gaagle
# Zone: tech
#
# First Name: roger
# Last Name: vogal
# Operator: email
# Zone: xyz
#
# First Name: adamtisler
# Last Name:
# Operator: gaagle
# Zone: xyz
#
# First Name: matthew3420
# Last Name:
# Operator: hotmoille
# Zone: tech
#
# First Name: john8770
# Last Name:
# Operator: napster
# Zone: hu
#
# First Name: hesch_zeller
# Last Name:
# Operator: email
# Zone: apple
#
# First Name: christensen_ben
# Last Name:
# Operator: proton
# Zone: com
#
# First Name: walter
# Last Name: soulis
# Operator: email
# Zone: com
#
# First Name: ben8671
# Last Name:
# Operator: proton
# Zone: tech
#
# First Name: frankjagtap
# Last Name:
# Operator: napster
# Zone: com
#
# First Name: peternuttle
# Last Name:
# Operator: napster
# Zone: gov
#
# First Name: victor8847
# Last Name:
# Operator: ecoin
# Zone: io
#
# First Name: ferry
# Last Name: paul
# Operator: imail
# Zone: org
#
# First Name: 690377034
# Last Name:
# Operator: gaagle
# Zone: apple
#
# First Name: lepageroger
# Last Name:
# Operator: proton
# Zone: gov
#
# First Name: john
# Last Name: zeaser
# Operator: imail
# Zone: gov
#
# First Name: 4709006
# Last Name:
# Operator: napster
# Zone: tech
#
# First Name: kaskel5284
# Last Name:
# Operator: belgaximus
# Zone: org
#
# First Name: hanktiernan
# Last Name:
# Operator: youhoo
# Zone: io
#
# First Name: ripka2474
# Last Name:
# Operator: hotmoille
# Zone: tech
#
# First Name: cataldi_matthew
# Last Name:
# Operator: odul
# Zone: me
#
# First Name: steve6967
# Last Name:
# Operator: odul
# Zone: hu
#
# First Name: irwincarl
# Last Name:
# Operator: belgaximus
# Zone: gov
#
# First Name: wakefieldjoe
# Last Name:
# Operator: ecoin
# Zone: org
#
# First Name: nathansagar
# Last Name:
# Operator: email
# Zone: apple
#
# First Name: hydinger_larry
# Last Name:
# Operator: odul
# Zone: xyz
#
# First Name: frank
# Last Name: yates
# Operator: proton
# Zone: gov
#
# First Name: schuster5868
# Last Name:
# Operator: youhoo
# Zone: tech
#
# First Name: rogerschwager
# Last Name:
# Operator: imail
# Zone: tech
#
# First Name: 163622426
# Last Name:
# Operator: imail
# Zone: com
#
# First Name: baxstercarl
# Last Name:
# Operator: proton
# Zone: net
#
# First Name: aikin
# Last Name:
# Operator: napster
# Zone: gov
#
# First Name: tisler_reyes
# Last Name:
# Operator: imail
# Zone: io
#
# First Name: monte1021
# Last Name:
# Operator: hotmoille
# Zone: gov
#
# First Name: quizoz
# Last Name:
# Operator: proton
# Zone: apple
#
# First Name: vail_soukup
# Last Name:
# Operator: proton
# Zone: apple
#
# First Name: thomassonderling
# Last Name:
# Operator: napster
# Zone: com
#
# First Name: frankaikin
# Last Name:
# Operator: odul
# Zone: io
#
# First Name: aaronillingsworth
# Last Name:
# Operator: hotmoille
# Zone: com
#
# First Name: 859491337
# Last Name:
# Operator: youhoo
# Zone: hu
#
# First Name: paul
# Last Name: eastman
# Operator: napster
# Zone: io
#
# First Name: waltertisler
# Last Name:
# Operator: belgaximus
# Zone: apple
#
# First Name: ferro_caswell
# Last Name:
# Operator: hotmoille
# Zone: com
#
# First Name: george
# Last Name:
# Operator: gaagle
# Zone: hu
#
# First Name: timorwig
# Last Name:
# Operator: email
# Zone: io
#
# First Name: jones
# Last Name:
# Operator: napster
# Zone: net
#
# First Name: hoffman
# Last Name: roger
# Operator: youhoo
# Zone: xyz
#
# First Name: matthew
# Last Name: trusela
# Operator: imail
# Zone: io
#
# First Name: larry2207
# Last Name:
# Operator: imail
# Zone: apple
#
# First Name: rice_sonderling
# Last Name:
# Operator: gaagle
# Zone: hu
#
# First Name: nuttleben
# Last Name:
# Operator: proton
# Zone: net
#
# First Name: dewalt_martin
# Last Name:
# Operator: belgaximus
# Zone: io
#
# First Name: ikekassing
# Last Name:
# Operator: gaagle
# Zone: com
#
# First Name: 240044289
# Last Name:
# Operator: odul
# Zone: tech
#
# First Name: otto
# Last Name:
# Operator: napster
# Zone: hu
#
# First Name: ferro
# Last Name: edward
# Operator: imail
# Zone: xyz
#
# First Name: hankanderson
# Last Name:
# Operator: imail
# Zone: net
#
# First Name: dan
# Last Name: deitz
# Operator: belgaximus
# Zone: gov
#
# First Name: orwig_sweeney
# Last Name:
# Operator: proton
# Zone: me
#
# First Name: bencaswell
# Last Name:
# Operator: youhoo
# Zone: apple
#
# First Name: chambers
# Last Name: victor
# Operator: email
# Zone: net
#
# First Name: 579081959
# Last Name:
# Operator: ecoin
# Zone: hu
#
# First Name: moore
# Last Name: fred
# Operator: imail
# Zone: com
#
# First Name: thomas
# Last Name:
# Operator: gaagle
# Zone: me
#
# First Name: orwig
# Last Name:
# Operator: imail
# Zone: tech
#
# First Name: hal
# Last Name:
# Operator: imail
# Zone: me
#
# First Name: alex9835
# Last Name:
# Operator: email
# Zone: org
#
# First Name: nathanripka
# Last Name:
# Operator: belgaximus
# Zone: com
#
# First Name: sonderling
# Last Name:
# Operator: napster
# Zone: xyz
#
# First Name: matthew
# Last Name: duffman
# Operator: gaagle
# Zone: net
#
# First Name: monte2098
# Last Name:
# Operator: odul
# Zone: io
#
# First Name: victor
# Last Name: tiernan
# Operator: email
# Zone: hu
#
# First Name: 822140569
# Last Name:
# Operator: proton
# Zone: net
#
# First Name: joe
# Last Name:
# Operator: hotmoille
# Zone: com
#
# First Name: matthew
# Last Name:
# Operator: gaagle
# Zone: tech
#
# First Name: walter
# Last Name:
# Operator: napster
# Zone: net
#
# First Name: yocum_ventotla
# Last Name:
# Operator: email
# Zone: tech
#
# First Name: vader_sweeney
# Last Name:
# Operator: ecoin
# Zone: hu
#
# First Name: orwig_mills
# Last Name:
# Operator: youhoo
# Zone: me
#
# First Name: roger7781
# Last Name:
# Operator: odul
# Zone: io
#
# First Name: dugan_thomas
# Last Name:
# Operator: odul
# Zone: tech
#
# First Name: vader
# Last Name:
# Operator: gaagle
# Zone: apple
#
# First Name: otto
# Last Name:
# Operator: gaagle
# Zone: xyz
#
# First Name: sawyer_johnson
# Last Name:
# Operator: hotmoille
# Zone: apple
#
# First Name: george
# Last Name:
# Operator: hotmoille
# Zone: net
#
# First Name: anderson
# Last Name: john
# Operator: hotmoille
# Zone: gov
#
# First Name: hydinger_aaron
# Last Name:
# Operator: ecoin
# Zone: com
#
# First Name: monte
# Last Name:
# Operator: hotmoille
# Zone: com
#
# First Name: severson_aaron
# Last Name:
# Operator: proton
# Zone: io
#
# First Name: jack
# Last Name: fletcher
# Operator: napster
# Zone: com
#
# First Name: jurgensonpaul
# Last Name:
# Operator: ecoin
# Zone: io
#
# First Name: 438861443
# Last Name:
# Operator: ecoin
# Zone: gov
#
# First Name: aaron
# Last Name:
# Operator: proton
# Zone: com
#
# First Name: doran
# Last Name:
# Operator: email
# Zone: org
#
# First Name: sweeney_nathan
# Last Name:
# Operator: proton
# Zone: xyz
#
# First Name: celedon_bauer
# Last Name:
# Operator: gaagle
# Zone: net
#
# First Name: ben
# Last Name: bongard
# Operator: hotmoille
# Zone: com
#
# First Name: 421931320
# Last Name:
# Operator: belgaximus
# Zone: gov
#
# First Name: cataldi_haworth
# Last Name:
# Operator: gaagle
# Zone: com
#
# First Name: 290273746
# Last Name:
# Operator: hotmoille
# Zone: me
#
# First Name: tybauer
# Last Name:
# Operator: imail
# Zone: apple
#
# First Name: larrymyers
# Last Name:
# Operator: hotmoille
# Zone: tech
#
# First Name: orymonte
# Last Name:
# Operator: youhoo
# Zone: me
#
# First Name: lawless
# Last Name: fred
# Operator: imail
# Zone: tech
#
# First Name: fredroot
# Last Name:
# Operator: odul
# Zone: com
#
# First Name: napier3011
# Last Name:
# Operator: email
# Zone: com
#
# First Name: tynapier
# Last Name:
# Operator: napster
# Zone: org
#
# First Name: ty3947
# Last Name:
# Operator: ecoin
# Zone: io
#
# First Name: ben
# Last Name:
# Operator: odul
# Zone: com
#
# First Name: sawyer
# Last Name:
# Operator: imail
# Zone: com
#
# First Name: schwager9365
# Last Name:
# Operator: hotmoille
# Zone: io
#
# First Name: aaronlewis
# Last Name:
# Operator: proton
# Zone: gov
#
# First Name: nelson_jack
# Last Name:
# Operator: gaagle
# Zone: apple
#
# First Name: upson1390
# Last Name:
# Operator: proton
# Zone: apple
#
# First Name: 871781143
# Last Name:
# Operator: odul
# Zone: org
#
# First Name: 269062053
# Last Name:
# Operator: youhoo
# Zone: me
#
# First Name: victorreardon
# Last Name:
# Operator: proton
# Zone: com
#
# First Name: soloman
# Last Name:
# Operator: gaagle
# Zone: tech
#
# First Name: aaronsagar
# Last Name:
# Operator: ecoin
# Zone: org
#
# First Name: alex
# Last Name:
# Operator: odul
# Zone: hu
#
# First Name: ike5340
# Last Name:
# Operator: email
# Zone: apple
#
# First Name: 120987413
# Last Name:
# Operator: email
# Zone: tech
#
# First Name: ziegler
# Last Name:
# Operator: hotmoille
# Zone: hu
#
# First Name: tisler
# Last Name: monte
# Operator: odul
# Zone: gov
#
# First Name: victorquinn
# Last Name:
# Operator: gaagle
# Zone: io
#
# First Name: aaronebner
# Last Name:
# Operator: youhoo
# Zone: apple
#
# First Name: fred
# Last Name: moore
# Operator: gaagle
# Zone: net
#
# First Name: adam3605
# Last Name:
# Operator: gaagle
# Zone: io
#
# First Name: stevewagle
# Last Name:
# Operator: napster
# Zone: com
#
# First Name: montedeitz
# Last Name:
# Operator: napster
# Zone: hu
#
# First Name: orwig_john
# Last Name:
# Operator: email
# Zone: org
#
# First Name: roger
# Last Name:
# Operator: napster
# Zone: apple
#
# First Name: edwarddeitz
# Last Name:
# Operator: gaagle
# Zone: tech
#
# First Name: 273554425
# Last Name:
# Operator: proton
# Zone: gov
#
# First Name: edward
# Last Name: darnell
# Operator: proton
# Zone: org
#
# First Name: marknapier
# Last Name:
# Operator: youhoo
# Zone: com
#
# First Name: upson
# Last Name: peter
# Operator: gaagle
# Zone: me
#
# First Name: john
# Last Name: stahl
# Operator: email
# Zone: xyz
#
# First Name: duffman
# Last Name: aaron
# Operator: proton
# Zone: hu
#
# First Name: jenson
# Last Name:
# Operator: hotmoille
# Zone: hu
#
# First Name: rogermcginnis
# Last Name:
# Operator: napster
# Zone: tech
#
# First Name: soukup
# Last Name:
# Operator: belgaximus
# Zone: gov
#
# First Name: soloman
# Last Name:
# Operator: odul
# Zone: apple
#
# First Name: 877692701
# Last Name:
# Operator: napster
# Zone: hu
#
# First Name: tandyaaron
# Last Name:
# Operator: ecoin
# Zone: tech
#
# First Name: ingramthomas
# Last Name:
# Operator: youhoo
# Zone: xyz
#
# First Name: aaron8129
# Last Name:
# Operator: belgaximus
# Zone: apple
#
# First Name: fredmills
# Last Name:
# Operator: imail
# Zone: net
#
# First Name: haljagtap
# Last Name:
# Operator: hotmoille
# Zone: org
#
# First Name: soloman_eastman
# Last Name:
# Operator: email
# Zone: com
#
# First Name: montelewis
# Last Name:
# Operator: gaagle
# Zone: org
#
# First Name: peter
# Last Name: mccord
# Operator: gaagle
# Zone: com
#
# First Name: roger
# Last Name:
# Operator: proton
# Zone: io
#
# First Name: paiser
# Last Name:
# Operator: youhoo
# Zone: gov
#
# First Name: ty
# Last Name:
# Operator: imail
# Zone: gov
#
# First Name: roberts
# Last Name:
# Operator: youhoo
# Zone: gov
#
# First Name: 958642438
# Last Name:
# Operator: email
# Zone: net
#
# First Name: boyd3853
# Last Name:
# Operator: belgaximus
# Zone: net
#
# First Name: soloman_nathan
# Last Name:
# Operator: youhoo
# Zone: gov
#
# First Name: 92101346
# Last Name:
# Operator: proton
# Zone: tech
#
# First Name: chambers
# Last Name: mark
# Operator: napster
# Zone: com
#
# First Name: nuttleedward
# Last Name:
# Operator: gaagle
# Zone: apple
#
# First Name: adamrice
# Last Name:
# Operator: ecoin
# Zone: net
#
# First Name: fred937
# Last Name:
# Operator: odul
# Zone: com
#
# First Name: ben
# Last Name:
# Operator: belgaximus
# Zone: hu
#
# First Name: dan
# Last Name:
# Operator: gaagle
# Zone: gov
#
# First Name: walterturco
# Last Name:
# Operator: imail
# Zone: tech
#
# First Name: roger
# Last Name: fletcher
# Operator: belgaximus
# Zone: xyz
#
# First Name: adamziegler
# Last Name:
# Operator: youhoo
# Zone: org
#
# First Name: 275056493
# Last Name:
# Operator: youhoo
# Zone: xyz
#
# First Name: peterlewis
# Last Name:
# Operator: belgaximus
# Zone: gov
#
# First Name: jack
# Last Name:
# Operator: imail
# Zone: net
#
# First Name: george3788
# Last Name:
# Operator: gaagle
# Zone: com
#
# First Name: zeller
# Last Name: roger
# Operator: youhoo
# Zone: me
#
# First Name: ottoschmitt
# Last Name:
# Operator: odul
# Zone: org
#
# First Name: tiernan
# Last Name: jack
# Operator: ecoin
# Zone: apple
#
# First Name: schutz_knutson
# Last Name:
# Operator: gaagle
# Zone: gov
#
# First Name: hal
# Last Name: severson
# Operator: youhoo
# Zone: hu
#
# First Name: mccord_ferry
# Last Name:
# Operator: odul
# Zone: gov
#
# First Name: uddin2208
# Last Name:
# Operator: youhoo
# Zone: me
#
# First Name: roger6727
# Last Name:
# Operator: imail
# Zone: me
#
# First Name: schlicht670
# Last Name:
# Operator: hotmoille
# Zone: net
#
# First Name: steve
# Last Name:
# Operator: odul
# Zone: xyz
#
# First Name: sawyer
# Last Name:
# Operator: napster
# Zone: apple
#
# First Name: soulis2863
# Last Name:
# Operator: belgaximus
# Zone: hu
#
# First Name: sonderling4257
# Last Name:
# Operator: email
# Zone: org
#
# First Name: upson_paul
# Last Name:
# Operator: gaagle
# Zone: org
#
# First Name: timtrebil
# Last Name:
# Operator: belgaximus
# Zone: tech
#
# First Name: 104036307
# Last Name:
# Operator: ecoin
# Zone: me
#
# First Name: frankupson
# Last Name:
# Operator: imail
# Zone: apple
#
# First Name: fietzeralex
# Last Name:
# Operator: youhoo
# Zone: hu
#
# First Name: solomanjohn
# Last Name:
# Operator: youhoo
# Zone: apple
#
# First Name: peter6564
# Last Name:
# Operator: email
# Zone: hu
#
# First Name: johnsen2199
# Last Name:
# Operator: gaagle
# Zone: tech
#
# First Name: lepage_edward
# Last Name:
# Operator: ecoin
# Zone: net
#
# First Name: dugelman8872
# Last Name:
# Operator: odul
# Zone: me
#
# First Name: vanderpoel_hydinger
# Last Name:
# Operator: odul
# Zone: xyz
#
# First Name: ripka2789
# Last Name:
# Operator: email
# Zone: io
#
# First Name: larry1596
# Last Name:
# Operator: imail
# Zone: tech
#
# First Name: moorety
# Last Name:
# Operator: napster
# Zone: io
#
# First Name: roger
# Last Name: fietzer
# Operator: belgaximus
# Zone: apple
#
# First Name: soulispeter
# Last Name:
# Operator: imail
# Zone: io
#
# First Name: ty3503
# Last Name:
# Operator: imail
# Zone: apple
#
# First Name: lepage_ostrander
# Last Name:
# Operator: hotmoille
# Zone: io
#
# First Name: vanderpoel_dan
# Last Name:
# Operator: gaagle
# Zone: net
#
# First Name: darnellty
# Last Name:
# Operator: gaagle
# Zone: org
#
# First Name: kalleg_david
# Last Name:
# Operator: belgaximus
# Zone: gov
#
# First Name: steve
# Last Name:
# Operator: odul
# Zone: apple
#
# First Name: lulloff
# Last Name: matthew
# Operator: proton
# Zone: hu
#
# First Name: chamberspaul
# Last Name:
# Operator: odul
# Zone: com
#
# First Name: bencasal
# Last Name:
# Operator: odul
# Zone: io
#
# First Name: vader_john
# Last Name:
# Operator: napster
# Zone: org
#
# First Name: lepage6698
# Last Name:
# Operator: email
# Zone: hu
#
# First Name: zeller_ziegler
# Last Name:
# Operator: ecoin
# Zone: tech
#
# First Name: walterschwager
# Last Name:
# Operator: email
# Zone: io
#
# First Name: christensenty
# Last Name:
# Operator: napster
# Zone: xyz
#
# First Name: severson_woo
# Last Name:
# Operator: proton
# Zone: org
#
# First Name: vailjoe
# Last Name:
# Operator: imail
# Zone: io
#
# First Name: dewalt_adam
# Last Name:
# Operator: proton
# Zone: net
#
# First Name: ziegler8928
# Last Name:
# Operator: imail
# Zone: net
#
# First Name: wakefield_edward
# Last Name:
# Operator: youhoo
# Zone: tech
#
# First Name: nugent1331
# Last Name:
# Operator: proton
# Zone: xyz
#
# First Name: celedon_severson
# Last Name:
# Operator: odul
# Zone: me
#
# First Name: ty
# Last Name: tiernan
# Operator: odul
# Zone: gov
#
# First Name: schmitt
# Last Name:
# Operator: imail
# Zone: org
#
# First Name: aaronwagle
# Last Name:
# Operator: email
# Zone: tech
#
# First Name: woo
# Last Name:
# Operator: hotmoille
# Zone: io
#
# First Name: tim9542
# Last Name:
# Operator: hotmoille
# Zone: tech
#
# First Name: john5694
# Last Name:
# Operator: email
# Zone: me
#
# First Name: sagar_nathan
# Last Name:
# Operator: belgaximus
# Zone: xyz
#
# First Name: larry
# Last Name: dinkins
# Operator: proton
# Zone: com
#
# First Name: severson
# Last Name: steve
# Operator: imail
# Zone: hu
#
# First Name: fredturco
# Last Name:
# Operator: odul
# Zone: net
#
# First Name: edward
# Last Name:
# Operator: youhoo
# Zone: com
#
# First Name: reyes
# Last Name: roger
# Operator: ecoin
# Zone: tech
#
# First Name: reamer_tim
# Last Name:
# Operator: hotmoille
# Zone: org
#
# First Name: steve3131
# Last Name:
# Operator: email
# Zone: tech
#
# First Name: wagner9136
# Last Name:
# Operator: gaagle
# Zone: apple
#
# First Name: davis_bowers
# Last Name:
# Operator: belgaximus
# Zone: me
#
# First Name: edward9079
# Last Name:
# Operator: napster
# Zone: net
#
# First Name: 283141330
# Last Name:
# Operator: gaagle
# Zone: hu
#
# First Name: tyduffman
# Last Name:
# Operator: hotmoille
# Zone: hu
#
# First Name: walterhydinger
# Last Name:
# Operator: ecoin
# Zone: io
#
# First Name: ben9635
# Last Name:
# Operator: odul
# Zone: apple
#
# First Name: vanderpoel
# Last Name: mark
# Operator: odul
# Zone: tech
#
# First Name: delorenzo
# Last Name: jack
# Operator: napster
# Zone: xyz
#
# First Name: nathan
# Last Name: woo
# Operator: proton
# Zone: org
#
# First Name: victorvader
# Last Name:
# Operator: belgaximus
# Zone: tech
#
# First Name: ben
# Last Name: irwin
# Operator: email
# Zone: net
#
# First Name: eastman_larry
# Last Name:
# Operator: napster
# Zone: apple
#
# First Name: sweeney_alex
# Last Name:
# Operator: hotmoille
# Zone: hu
#
# First Name: hydinger_otto
# Last Name:
# Operator: email
# Zone: apple
#
# First Name: peter2600
# Last Name:
# Operator: belgaximus
# Zone: apple
#
# First Name: eastman_adam
# Last Name:
# Operator: imail
# Zone: xyz
#
# First Name: thomas
# Last Name:
# Operator: gaagle
# Zone: com
#
# First Name: hal
# Last Name:
# Operator: napster
# Zone: gov
#
# First Name: paulresnick
# Last Name:
# Operator: gaagle
# Zone: me
#
# First Name: 682804922
# Last Name:
# Operator: ecoin
# Zone: hu
#
# First Name: myerspeter
# Last Name:
# Operator: youhoo
# Zone: me
#
# First Name: fred67
# Last Name:
# Operator: youhoo
# Zone: net
#
# First Name: edwardhoffman
# Last Name:
# Operator: napster
# Zone: apple
#
# First Name: thompson_orwig
# Last Name:
# Operator: napster
# Zone: com
#
# First Name: ike
# Last Name: stahl
# Operator: hotmoille
# Zone: apple
#
# First Name: markhoffman
# Last Name:
# Operator: imail
# Zone: org
#
# First Name: 669214282
# Last Name:
# Operator: imail
# Zone: com
#
# First Name: hank
# Last Name:
# Operator: proton
# Zone: com
#
# First Name: pettigrew_bauer
# Last Name:
# Operator: youhoo
# Zone: hu
#
# First Name: nuttle_upson
# Last Name:
# Operator: ecoin
# Zone: com
#
# First Name: danziegler
# Last Name:
# Operator: hotmoille
# Zone: tech
#
# First Name: nugent_uddin
# Last Name:
# Operator: belgaximus
# Zone: com
#
# First Name: alex
# Last Name: mccormack
# Operator: hotmoille
# Zone: com
#
# First Name: larry
# Last Name:
# Operator: youhoo
# Zone: hu
#
# First Name: deitzdan
# Last Name:
# Operator: imail
# Zone: apple
#
# First Name: alexhesch
# Last Name:
# Operator: odul
# Zone: gov
#
# First Name: dinkinscarl
# Last Name:
# Operator: napster
# Zone: io
#
# First Name: edward
# Last Name:
# Operator: imail
# Zone: tech
#
# First Name: 43720854
# Last Name:
# Operator: ecoin
# Zone: net
#
# First Name: tiernanotto
# Last Name:
# Operator: hotmoille
# Zone: xyz
#
# First Name: 220923632
# Last Name:
# Operator: proton
# Zone: xyz
#
# First Name: vader_larry
# Last Name:
# Operator: belgaximus
# Zone: io
#
# First Name: lepage
# Last Name:
# Operator: odul
# Zone: io
#
# First Name: woofrank
# Last Name:
# Operator: youhoo
# Zone: hu
#
# First Name: 413352781
# Last Name:
# Operator: imail
# Zone: xyz
#
# First Name: walterschutz
# Last Name:
# Operator: imail
# Zone: apple
#
# First Name: ike
# Last Name:
# Operator: proton
# Zone: xyz
#
# First Name: tislerjohn
# Last Name:
# Operator: napster
# Zone: org
#
# First Name: ebner_chapman
# Last Name:
# Operator: email
# Zone: me
#
# First Name: jurgenson
# Last Name: mark
# Operator: odul
# Zone: net
#
# First Name: 40053022
# Last Name:
# Operator: belgaximus
# Zone: apple
#
# First Name: nathanhylan
# Last Name:
# Operator: gaagle
# Zone: io
#
# First Name: carl1266
# Last Name:
# Operator: proton
# Zone: me
#
# First Name: ortiz
# Last Name:
# Operator: gaagle
# Zone: hu
#
# First Name: irwin_otto
# Last Name:
# Operator: proton
# Zone: hu
#
# First Name: ikechapman
# Last Name:
# Operator: youhoo
# Zone: io
#
# First Name: nathan
# Last Name: zeller
# Operator: odul
# Zone: me
#
# First Name: joeuddin
# Last Name:
# Operator: ecoin
# Zone: me
#
# First Name: lawicki
# Last Name:
# Operator: gaagle
# Zone: org
#
# First Name: casal9156
# Last Name:
# Operator: belgaximus
# Zone: com
#
# First Name: resnick2754
# Last Name:
# Operator: youhoo
# Zone: xyz
#
# First Name: ashwoon_hank
# Last Name:
# Operator: odul
# Zone: io
#
# First Name: jack3740
# Last Name:
# Operator: proton
# Zone: xyz
#
# First Name: hal
# Last Name: casal
# Operator: hotmoille
# Zone: com
#
# First Name: jurgenson_dan
# Last Name:
# Operator: napster
# Zone: hu
#
# First Name: 393543398
# Last Name:
# Operator: proton
# Zone: hu
#
# First Name: steve5769
# Last Name:
# Operator: proton
# Zone: apple
#
# First Name: duffman_vanderpoel
# Last Name:
# Operator: odul
# Zone: com
#
# First Name: 735354722
# Last Name:
# Operator: hotmoille
# Zone: gov
#
# First Name: monteschiebel
# Last Name:
# Operator: odul
# Zone: tech
#
# First Name: larry
# Last Name: miller
# Operator: youhoo
# Zone: tech
#
# First Name: duffmanedward
# Last Name:
# Operator: email
# Zone: me
#
# First Name: tim
# Last Name: roberts
# Operator: ecoin
# Zone: xyz
#
# First Name: schickowski
# Last Name: matthew
# Operator: napster
# Zone: com
#
# First Name: steve
# Last Name:
# Operator: youhoo
# Zone: gov
#
# First Name: duffman_weiss
# Last Name:
# Operator: proton
# Zone: gov
#
# First Name: rogersty
# Last Name:
# Operator: hotmoille
# Zone: hu
#
# First Name: paulchapman
# Last Name:
# Operator: imail
# Zone: xyz
#
# First Name: bongardben
# Last Name:
# Operator: napster
# Zone: tech
#
# First Name: ory_joe
# Last Name:
# Operator: belgaximus
# Zone: com
#
# First Name: cannon_ferro
# Last Name:
# Operator: ecoin
# Zone: apple
#
# First Name: rice_soulis
# Last Name:
# Operator: ecoin
# Zone: apple
#
# First Name: 579097737
# Last Name:
# Operator: belgaximus
# Zone: hu
#
# First Name: pettigrewfred
# Last Name:
# Operator: odul
# Zone: net
#
# First Name: victorillingsworth
# Last Name:
# Operator: ecoin
# Zone: org
#
# First Name: wagnercarl
# Last Name:
# Operator: proton
# Zone: net
#
# First Name: fred
# Last Name:
# Operator: imail
# Zone: io
#
# First Name: christensen
# Last Name:
# Operator: belgaximus
# Zone: hu
#
# First Name: vail
# Last Name:
# Operator: gaagle
# Zone: com
#
# First Name: nathan
# Last Name:
# Operator: imail
# Zone: hu
#
# First Name: victorjones
# Last Name:
# Operator: napster
# Zone: tech
#
# First Name: resnick
# Last Name: david
# Operator: odul
# Zone: apple
#
# First Name: roger
# Last Name:
# Operator: proton
# Zone: net
#
# First Name: resnick
# Last Name: thomas
# Operator: imail
# Zone: apple
#
# First Name: soukup_tim
# Last Name:
# Operator: odul
# Zone: apple
#
# First Name: hank
# Last Name:
# Operator: hotmoille
# Zone: org
#
# First Name: victorfletcher
# Last Name:
# Operator: imail
# Zone: tech
#
# First Name: schwager_pak
# Last Name:
# Operator: odul
# Zone: tech
#
# First Name: weinsteintim
# Last Name:
# Operator: proton
# Zone: org
#
# First Name: fred2414
# Last Name:
# Operator: hotmoille
# Zone: apple
#
# First Name: hesch1648
# Last Name:
# Operator: imail
# Zone: tech
#
# First Name: weiss_walter
# Last Name:
# Operator: gaagle
# Zone: com
#
# First Name: ottoreamer
# Last Name:
# Operator: email
# Zone: apple
#
# First Name: timbauer
# Last Name:
# Operator: ecoin
# Zone: apple
#
# First Name: ike
# Last Name: reyes
# Operator: belgaximus
# Zone: gov
#
# First Name: matthew
# Last Name:
# Operator: hotmoille
# Zone: com
#
# First Name: reardon
# Last Name:
# Operator: gaagle
# Zone: hu
#
# First Name: mccormack7946
# Last Name:
# Operator: youhoo
# Zone: me
#
# First Name: matthew6993
# Last Name:
# Operator: hotmoille
# Zone: org
#
# First Name: mcginnis
# Last Name: walter
# Operator: email
# Zone: io
#
# First Name: mark2192
# Last Name:
# Operator: youhoo
# Zone: xyz
#
# First Name: dan
# Last Name:
# Operator: hotmoille
# Zone: tech
#
# First Name: nuttlety
# Last Name:
# Operator: gaagle
# Zone: gov
#
# First Name: victortisler
# Last Name:
# Operator: youhoo
# Zone: com
#
# First Name: tisler_cannon
# Last Name:
# Operator: youhoo
# Zone: apple
#
# First Name: jacksolberg
# Last Name:
# Operator: gaagle
# Zone: me
#
# First Name: nathan
# Last Name: vanderpoel
# Operator: belgaximus
# Zone: tech
#
# First Name: fletcher_duffman
# Last Name:
# Operator: ecoin
# Zone: com
#
# First Name: dugan_ortiz
# Last Name:
# Operator: hotmoille
# Zone: io
#
# First Name: anderson_dewalt
# Last Name:
# Operator: odul
# Zone: me
#
# First Name: adampak
# Last Name:
# Operator: hotmoille
# Zone: net
#
# First Name: peter
# Last Name: norquist
# Operator: napster
# Zone: net
#
# First Name: yang
# Last Name:
# Operator: imail
# Zone: net
#
# First Name: alex7627
# Last Name:
# Operator: youhoo
# Zone: gov
#
# First Name: ben
# Last Name:
# Operator: napster
# Zone: xyz
#
# First Name: weiss9401
# Last Name:
# Operator: youhoo
# Zone: xyz
#
# First Name: haworth_steve
# Last Name:
# Operator: youhoo
# Zone: gov
#
# First Name: ulrich9331
# Last Name:
# Operator: email
# Zone: org
#
# First Name: baxster
# Last Name: mark
# Operator: email
# Zone: net
#
# First Name: dugelman2727
# Last Name:
# Operator: odul
# Zone: xyz
#
# First Name: yates_hal
# Last Name:
# Operator: odul
# Zone: net
#
# First Name: otto1543
# Last Name:
# Operator: youhoo
# Zone: gov
#
# First Name: bateman_joe
# Last Name:
# Operator: odul
# Zone: apple
#
# First Name: larryhoffman
# Last Name:
# Operator: belgaximus
# Zone: tech
#
# First Name: celedonmatthew
# Last Name:
# Operator: napster
# Zone: net
#
# First Name: victorrogers
# Last Name:
# Operator: gaagle
# Zone: net
#
# First Name: ashwoon_ben
# Last Name:
# Operator: napster
# Zone: net
#
# First Name: 711978855
# Last Name:
# Operator: email
# Zone: org
#
# First Name: delorenzo
# Last Name:
# Operator: belgaximus
# Zone: xyz
#
# First Name: zeller_john
# Last Name:
# Operator: napster
# Zone: hu
#
# First Name: olson
# Last Name:
# Operator: odul
# Zone: gov
#
# First Name: bensoukup
# Last Name:
# Operator: proton
# Zone: me
#
# First Name: sweeneytim
# Last Name:
# Operator: ecoin
# Zone: gov
#
# First Name: joe
# Last Name:
# Operator: proton
# Zone: hu
#
# First Name: doran
# Last Name:
# Operator: proton
# Zone: tech
#
# First Name: otto
# Last Name:
# Operator: hotmoille
# Zone: gov
#
# First Name: frankchristensen
# Last Name:
# Operator: odul
# Zone: me
#
# First Name: 524504262
# Last Name:
# Operator: odul
# Zone: me
#
# First Name: tim3793
# Last Name:
# Operator: gaagle
# Zone: io
#
# First Name: otto815
# Last Name:
# Operator: email
# Zone: me
#
# First Name: sweeney
# Last Name: carl
# Operator: gaagle
# Zone: net
#
# First Name: knutson_trebil
# Last Name:
# Operator: email
# Zone: me
#
# First Name: jack
# Last Name: weinstein
# Operator: email
# Zone: apple
#
# First Name: victor
# Last Name:
# Operator: proton
# Zone: hu
#
# First Name: hancockcarl
# Last Name:
# Operator: napster
# Zone: com
#
# First Name: schlicht
# Last Name: dan
# Operator: email
# Zone: tech
#
# First Name: tisler3297
# Last Name:
# Operator: belgaximus
# Zone: tech
#
# First Name: steve6502
# Last Name:
# Operator: email
# Zone: net
#
# First Name: frank5506
# Last Name:
# Operator: imail
# Zone: apple
#
# First Name: schwager_joe
# Last Name:
# Operator: napster
# Zone: org
#
# First Name: weiss5261
# Last Name:
# Operator: email
# Zone: tech
#
# First Name: dantrusela
# Last Name:
# Operator: odul
# Zone: org
#
# First Name: leisinger_walter
# Last Name:
# Operator: hotmoille
# Zone: org
#
# First Name: roger4965
# Last Name:
# Operator: odul
# Zone: net
#
# First Name: mccormack_ike
# Last Name:
# Operator: youhoo
# Zone: hu
#
# First Name: jackortiz
# Last Name:
# Operator: imail
# Zone: com
#
# First Name: ferro_peter
# Last Name:
# Operator: ecoin
# Zone: apple
#
# First Name: schmitt
# Last Name:
# Operator: imail
# Zone: apple
#
# First Name: yates
# Last Name: thomas
# Operator: belgaximus
# Zone: org
#
# First Name: schutzike
# Last Name:
# Operator: ecoin
# Zone: tech
#
# First Name: upson
# Last Name:
# Operator: hotmoille
# Zone: hu
#
# First Name: schlicht
# Last Name: monte
# Operator: hotmoille
# Zone: com
#
# First Name: upson
# Last Name:
# Operator: youhoo
# Zone: com
#
# First Name: 525072400
# Last Name:
# Operator: proton
# Zone: tech
#
# First Name: jurgenson_trusela
# Last Name:
# Operator: odul
# Zone: me
#
# First Name: georgeturco
# Last Name:
# Operator: imail
# Zone: hu
#
# First Name: jenson9642
# Last Name:
# Operator: proton
# Zone: io
#
# First Name: thomascaswell
# Last Name:
# Operator: napster
# Zone: io
#
# First Name: thomaskalleg
# Last Name:
# Operator: ecoin
# Zone: xyz
#
# First Name: bowers
# Last Name: steve
# Operator: napster
# Zone: io
#
# First Name: victorresnick
# Last Name:
# Operator: proton
# Zone: org
#
# First Name: sellon_roger
# Last Name:
# Operator: proton
# Zone: hu
#
# First Name: peter
# Last Name:
# Operator: hotmoille
# Zone: com
#
# First Name: victor2700
# Last Name:
# Operator: napster
# Zone: xyz
#
# First Name: hesch_mills
# Last Name:
# Operator: ecoin
# Zone: org
#
# First Name: frankwoo
# Last Name:
# Operator: napster
# Zone: gov
#
# First Name: ulrich_carl
# Last Name:
# Operator: belgaximus
# Zone: hu
#
# First Name: hoffman
# Last Name:
# Operator: hotmoille
# Zone: hu
#
# First Name: zellersteve
# Last Name:
# Operator: napster
# Zone: io
#
# First Name: jonesthomas
# Last Name:
# Operator: email
# Zone: tech
#
# First Name: jagtap_victor
# Last Name:
# Operator: email
# Zone: gov
#
# First Name: reyes3325
# Last Name:
# Operator: youhoo
# Zone: gov
#
# First Name: schickowski7190
# Last Name:
# Operator: odul
# Zone: tech
#
# First Name: irwin
# Last Name:
# Operator: odul
# Zone: hu
#
# First Name: moore_edward
# Last Name:
# Operator: youhoo
# Zone: org
#
# First Name: tisler_fred
# Last Name:
# Operator: imail
# Zone: apple
#
# First Name: thomas
# Last Name:
# Operator: email
# Zone: xyz
#
# First Name: alexcataldi
# Last Name:
# Operator: napster
# Zone: org
#
# First Name: hankulrich
# Last Name:
# Operator: belgaximus
# Zone: hu
#
# First Name: peter
# Last Name: moody
# Operator: proton
# Zone: io
#
# First Name: ben
# Last Name: weinstein
# Operator: odul
# Zone: apple
#
# First Name: davidson_jack
# Last Name:
# Operator: youhoo
# Zone: xyz
#
# First Name: jacksellon
# Last Name:
# Operator: napster
# Zone: io
#
# First Name: cataldiedward
# Last Name:
# Operator: hotmoille
# Zone: io
#
# First Name: sellon
# Last Name: jack
# Operator: ecoin
# Zone: net
#
# First Name: 748522766
# Last Name:
# Operator: gaagle
# Zone: xyz
#
# First Name: victorsweeney
# Last Name:
# Operator: odul
# Zone: tech
#
# First Name: johnmoody
# Last Name:
# Operator: imail
# Zone: xyz
#
# First Name: peter
# Last Name: sandstrom
# Operator: napster
# Zone: xyz
#
# First Name: montelulloff
# Last Name:
# Operator: email
# Zone: io
#
# First Name: andersonhal
# Last Name:
# Operator: odul
# Zone: apple
#
# First Name: napier_hank
# Last Name:
# Operator: belgaximus
# Zone: hu
#
# First Name: moodygeorge
# Last Name:
# Operator: proton
# Zone: net
#
# First Name: peter4809
# Last Name:
# Operator: email
# Zone: net
#
# First Name: marknapier
# Last Name:
# Operator: proton
# Zone: io
#
# First Name: darnell_roger
# Last Name:
# Operator: hotmoille
# Zone: net
#
# First Name: george
# Last Name:
# Operator: belgaximus
# Zone: gov
#
# First Name: tim
# Last Name: weinstein
# Operator: odul
# Zone: io
#
# First Name: pak_roger
# Last Name:
# Operator: proton
# Zone: com
#
# First Name: georgecasal
# Last Name:
# Operator: hotmoille
# Zone: tech
#
# First Name: fred
# Last Name: martin
# Operator: youhoo
# Zone: apple
#
# First Name: alex
# Last Name:
# Operator: proton
# Zone: apple
#
# First Name: dan
# Last Name: ventotla
# Operator: proton
# Zone: gov
#
# First Name: dewalt_joe
# Last Name:
# Operator: email
# Zone: com
#
# First Name: celedon_hesch
# Last Name:
# Operator: youhoo
# Zone: net
#
# First Name: ty8684
# Last Name:
# Operator: odul
# Zone: apple
#
# First Name: nuttle_yang
# Last Name:
# Operator: youhoo
# Zone: hu
#
# First Name: hal
# Last Name: rice
# Operator: napster
# Zone: com
#
# First Name: 821663824
# Last Name:
# Operator: odul
# Zone: apple
#
# First Name: mccord
# Last Name: fred
# Operator: proton
# Zone: apple
#
# First Name: orwig
# Last Name:
# Operator: ecoin
# Zone: xyz
#
# First Name: turcolarry
# Last Name:
# Operator: gaagle
# Zone: hu
#
# First Name: mcginnis_aaron
# Last Name:
# Operator: email
# Zone: com
#
# First Name: johnpettigrew
# Last Name:
# Operator: proton
# Zone: hu
#
# First Name: hal
# Last Name: yocum
# Operator: email
# Zone: apple
#
# First Name: monteschuster
# Last Name:
# Operator: belgaximus
# Zone: gov
#
# First Name: fietzer_mark
# Last Name:
# Operator: gaagle
# Zone: tech
#
# First Name: 271794997
# Last Name:
# Operator: imail
# Zone: gov
#
# First Name: hancock
# Last Name:
# Operator: imail
# Zone: tech
#
# First Name: wagle_doran
# Last Name:
# Operator: hotmoille
# Zone: hu
#
# First Name: 558791202
# Last Name:
# Operator: napster
# Zone: io
#
# First Name: quinn1097
# Last Name:
# Operator: imail
# Zone: org
#
# First Name: sawyer
# Last Name:
# Operator: proton
# Zone: hu
#
# First Name: ory7664
# Last Name:
# Operator: belgaximus
# Zone: net
#
# First Name: olsonjohn
# Last Name:
# Operator: belgaximus
# Zone: tech
#
# First Name: knutson_matthew
# Last Name:
# Operator: odul
# Zone: tech
#
# First Name: aikin7996
# Last Name:
# Operator: belgaximus
# Zone: tech
#
# First Name: dewalt674
# Last Name:
# Operator: napster
# Zone: io
#
# First Name: ventotla_haworth
# Last Name:
# Operator: imail
# Zone: tech
#
# First Name: ike
# Last Name:
# Operator: ecoin
# Zone: apple
#
# First Name: yates
# Last Name: hal
# Operator: odul
# Zone: io
#
# First Name: resnick_john
# Last Name:
# Operator: napster
# Zone: xyz
#
# First Name: roger
# Last Name: deitz
# Operator: gaagle
# Zone: org
#
# First Name: pak
# Last Name: matthew
# Operator: gaagle
# Zone: gov
#
# First Name: edward
# Last Name:
# Operator: odul
# Zone: io
#
# First Name: markmoore
# Last Name:
# Operator: email
# Zone: tech
#
# First Name: schickowski
# Last Name: roger
# Operator: hotmoille
# Zone: net
#
# First Name: larrysandstrom
# Last Name:
# Operator: odul
# Zone: org
#
# First Name: nathan
# Last Name:
# Operator: napster
# Zone: gov
#
# First Name: nathan
# Last Name: rogers
# Operator: odul
# Zone: gov
#
# First Name: adameastman
# Last Name:
# Operator: email
# Zone: me
#
# First Name: carl
# Last Name: mcginnis
# Operator: email
# Zone: apple
#
# First Name: davidashwoon
# Last Name:
# Operator: belgaximus
# Zone: tech
#
# First Name: sawyer
# Last Name: steve
# Operator: imail
# Zone: me
#
# First Name: rogercannon
# Last Name:
# Operator: youhoo
# Zone: io
#
# First Name: aaron
# Last Name:
# Operator: hotmoille
# Zone: gov
#
# First Name: celedon_ostrander
# Last Name:
# Operator: email
# Zone: gov
#
# First Name: rogerhoffman
# Last Name:
# Operator: email
# Zone: apple
#
# First Name: victor2949
# Last Name:
# Operator: hotmoille
# Zone: org
#
# First Name: matthew
# Last Name: schwager
# Operator: imail
# Zone: com
#
# First Name: dan9862
# Last Name:
# Operator: ecoin
# Zone: com
#
# First Name: victor3334
# Last Name:
# Operator: belgaximus
# Zone: apple
#
# First Name: trebil
# Last Name:
# Operator: ecoin
# Zone: gov
#
# First Name: 786331264
# Last Name:
# Operator: napster
# Zone: me
#
# First Name: tyjohnson
# Last Name:
# Operator: gaagle
# Zone: xyz
#
# First Name: valente5120
# Last Name:
# Operator: imail
# Zone: net
#
# First Name: 187630443
# Last Name:
# Operator: imail
# Zone: net
#
# First Name: 926609635
# Last Name:
# Operator: odul
# Zone: com
#
# First Name: john
# Last Name:
# Operator: hotmoille
# Zone: tech
#
# First Name: myers6475
# Last Name:
# Operator: email
# Zone: org
#
# First Name: ortiz8400
# Last Name:
# Operator: napster
# Zone: apple
#
# First Name: sandstromgeorge
# Last Name:
# Operator: hotmoille
# Zone: net
#
# First Name: hylan_tandy
# Last Name:
# Operator: odul
# Zone: tech
#
# First Name: adammccord
# Last Name:
# Operator: napster
# Zone: org
#
# First Name: matthew3862
# Last Name:
# Operator: odul
# Zone: apple
#
# First Name: david8084
# Last Name:
# Operator: proton
# Zone: tech
#
# First Name: johnmills
# Last Name:
# Operator: ecoin
# Zone: tech
#
# ...
#
# First Name: orwig
# Last Name:
# Operator: imail
# Zone: me
#
# First Name: turco_eastman
# Last Name:
# Operator: gaagle
# Zone: apple
#
# First Name: ziegler8032
# Last Name:
# Operator: gaagle
# Zone: tech
#
# First Name: stevemiller
# Last Name:
# Operator: proton
# Zone: apple
#
# First Name: 97234842
# Last Name:
# Operator: imail
# Zone: net
#
# First Name: reardon9212
# Last Name:
# Operator: proton
# Zone: gov
#
# First Name: paul
# Last Name: myers
# Operator: email
# Zone: gov
#
# First Name: jack7787
# Last Name:
# Operator: belgaximus
# Zone: net
#
# First Name: jagtap_larry
# Last Name:
# Operator: belgaximus
# Zone: org
#
# First Name: otto
# Last Name: leisinger
# Operator: proton
# Zone: io
#
# First Name: yates_thomas
# Last Name:
# Operator: ecoin
# Zone: xyz
#
# First Name: knutson_thomas
# Last Name:
# Operator: email
# Zone: com
#
# First Name: davis
# Last Name: monte
# Operator: hotmoille
# Zone: net
#
# First Name: vader_alex
# Last Name:
# Operator: odul
# Zone: xyz
#
# First Name: nuttle1626
# Last Name:
# Operator: imail
# Zone: hu
#
# First Name: 738731613
# Last Name:
# Operator: email
# Zone: io
#
# First Name: hesch
# Last Name: hank
# Operator: email
# Zone: me
#
# First Name: monte6198
# Last Name:
# Operator: imail
# Zone: me
#
# First Name: alexhydinger
# Last Name:
# Operator: gaagle
# Zone: gov
#
# First Name: schuster_tiernan
# Last Name:
# Operator: email
# Zone: xyz
#
# First Name: victorkeller
# Last Name:
# Operator: proton
# Zone: net
#
# First Name: illingsworth
# Last Name: monte
# Operator: belgaximus
# Zone: apple
#
# First Name: peter
# Last Name:
# Operator: belgaximus
# Zone: net
#
# First Name: hoffman9254
# Last Name:
# Operator: odul
# Zone: tech
#
# First Name: sandstrom6021
# Last Name:
# Operator: belgaximus
# Zone: gov
#
# First Name: moody_lawless
# Last Name:
# Operator: youhoo
# Zone: tech
#
# First Name: 622921665
# Last Name:
# Operator: belgaximus
# Zone: org
#
# First Name: wagner
# Last Name:
# Operator: ecoin
# Zone: me
#
# First Name: 498202212
# Last Name:
# Operator: odul
# Zone: tech
#
# First Name: thompson2886
# Last Name:
# Operator: belgaximus
# Zone: org
#
# First Name: alexfrick
# Last Name:
# Operator: email
# Zone: xyz
#
# First Name: zeller
# Last Name: matthew
# Operator: imail
# Zone: com
#
# First Name: thomasjagtap
# Last Name:
# Operator: proton
# Zone: hu
#
# First Name: stahl_solberg
# Last Name:
# Operator: proton
# Zone: hu
#
# First Name: resnick
# Last Name:
# Operator: youhoo
# Zone: me
#
# First Name: 881606408
# Last Name:
# Operator: imail
# Zone: io
#
# First Name: hank4616
# Last Name:
# Operator: proton
# Zone: gov
#
# First Name: thomas
# Last Name: reamer
# Operator: odul
# Zone: hu
#
# First Name: turco
# Last Name:
# Operator: hotmoille
# Zone: tech
#
# First Name: matthew
# Last Name: doran
# Operator: odul
# Zone: hu
#
# First Name: frick_steve
# Last Name:
# Operator: napster
# Zone: gov
#
# First Name: edwarddinkins
# Last Name:
# Operator: imail
# Zone: com
#
# First Name: 35834059
# Last Name:
# Operator: proton
# Zone: com
#
# First Name: paul7873
# Last Name:
# Operator: ecoin
# Zone: com
#
# First Name: upson_quinn
# Last Name:
# Operator: youhoo
# Zone: tech
#
# First Name: peteryocum
# Last Name:
# Operator: proton
# Zone: io
#
# First Name: 200912703
# Last Name:
# Operator: youhoo
# Zone: org
#
# First Name: hank2763
# Last Name:
# Operator: imail
# Zone: io
#
# First Name: roger4911
# Last Name:
# Operator: hotmoille
# Zone: apple
#
# First Name: thompsonlarry
# Last Name:
# Operator: email
# Zone: net
#
# First Name: ebner_casal
# Last Name:
# Operator: hotmoille
# Zone: com
#
# First Name: moodyroger
# Last Name:
# Operator: ecoin
# Zone: com
#
# First Name: delorenzo_adam
# Last Name:
# Operator: hotmoille
# Zone: org
#
# First Name: dan
# Last Name: delorenzo
# Operator: proton
# Zone: xyz
#
# First Name: knutsondavid
# Last Name:
# Operator: napster
# Zone: me
#
# First Name: hal2231
# Last Name:
# Operator: hotmoille
# Zone: me
#
# First Name: quinn_aikin
# Last Name:
# Operator: hotmoille
# Zone: net
#
# First Name: trebilroger
# Last Name:
# Operator: belgaximus
# Zone: com
#
# First Name: tiernanmark
# Last Name:
# Operator: odul
# Zone: apple
#
# First Name: olson
# Last Name: george
# Operator: odul
# Zone: tech
#
# First Name: reamer
# Last Name:
# Operator: imail
# Zone: hu
#
# First Name: haworth9991
# Last Name:
# Operator: email
# Zone: gov
#
# First Name: robertsmark
# Last Name:
# Operator: imail
# Zone: gov
#
# First Name: jack
# Last Name:
# Operator: belgaximus
# Zone: com
#
# First Name: trussel
# Last Name:
# Operator: youhoo
# Zone: hu
#
# First Name: jackupson
# Last Name:
# Operator: proton
# Zone: xyz
#
# First Name: nugent6976
# Last Name:
# Operator: napster
# Zone: com
#
# First Name: martin_kaskel
# Last Name:
# Operator: hotmoille
# Zone: gov
#
# First Name: halquinn
# Last Name:
# Operator: belgaximus
# Zone: com
#
# First Name: vail
# Last Name: frank
# Operator: hotmoille
# Zone: apple
#
# First Name: nuttlesteve
# Last Name:
# Operator: odul
# Zone: me
#
# First Name: nathan
# Last Name: yocum
# Operator: ecoin
# Zone: apple
#
# First Name: victorknutson
# Last Name:
# Operator: proton
# Zone: io
#
# First Name: kaskel
# Last Name:
# Operator: ecoin
# Zone: me
#
# First Name: 72032888
# Last Name:
# Operator: email
# Zone: me
#
# First Name: joe
# Last Name: nuttle
# Operator: youhoo
# Zone: io
#
# First Name: nathan3403
# Last Name:
# Operator: napster
# Zone: apple
#
# First Name: aaron
# Last Name:
# Operator: imail
# Zone: me
#
# First Name: aaron1573
# Last Name:
# Operator: odul
# Zone: net
#
# First Name: benmoody
# Last Name:
# Operator: proton
# Zone: io
#
# First Name: 916085653
# Last Name:
# Operator: napster
# Zone: hu
#
# First Name: knutson
# Last Name: tim
# Operator: napster
# Zone: io
#
# First Name: schickowski_tapia
# Last Name:
# Operator: hotmoille
# Zone: tech
#
# First Name: john5147
# Last Name:
# Operator: napster
# Zone: gov
#
# First Name: fredlawicki
# Last Name:
# Operator: hotmoille
# Zone: me
#
# First Name: nathan
# Last Name:
# Operator: ecoin
# Zone: net
#
# First Name: reardon
# Last Name: ben
# Operator: ecoin
# Zone: net
#
# First Name: kellerhal
# Last Name:
# Operator: proton
# Zone: tech
#
# First Name: kalleg_nathan
# Last Name:
# Operator: ecoin
# Zone: hu
#
# First Name: roger
# Last Name: dinkins
# Operator: proton
# Zone: io
#
# First Name: johnsen_cataldi
# Last Name:
# Operator: napster
# Zone: io
#
# First Name: hal
# Last Name: wagner
# Operator: imail
# Zone: com
#
# First Name: bongard
# Last Name:
# Operator: hotmoille
# Zone: tech
#
# First Name: bowers_ulrich
# Last Name:
# Operator: email
# Zone: me
#
# First Name: nelsonroger
# Last Name:
# Operator: gaagle
# Zone: xyz
#
# First Name: lewis_ortiz
# Last Name:
# Operator: proton
# Zone: me
#
# First Name: reyes_steve
# Last Name:
# Operator: gaagle
# Zone: apple
#
# First Name: martin
# Last Name: edward
# Operator: odul
# Zone: org
#
# First Name: ike1526
# Last Name:
# Operator: ecoin
# Zone: net
#
# First Name: 76134991
# Last Name:
# Operator: imail
# Zone: hu
#
# First Name: aaron
# Last Name: pak
# Operator: imail
# Zone: tech
#
# First Name: 819378036
# Last Name:
# Operator: proton
# Zone: com
#
# First Name: ty9361
# Last Name:
# Operator: gaagle
# Zone: xyz
#
# First Name: frankwoo
# Last Name:
# Operator: belgaximus
# Zone: hu
#
# First Name: solberg
# Last Name:
# Operator: belgaximus
# Zone: hu
#
# First Name: turco
# Last Name:
# Operator: odul
# Zone: apple
#
# First Name: ashwoonthomas
# Last Name:
# Operator: odul
# Zone: gov
#
# First Name: kaskel
# Last Name: tim
# Operator: youhoo
# Zone: org
#
# First Name: larry8418
# Last Name:
# Operator: belgaximus
# Zone: me
#
# First Name: tandyty
# Last Name:
# Operator: email
# Zone: xyz
#
# First Name: bauer_ripka
# Last Name:
# Operator: odul
# Zone: xyz
#
# First Name: 866926931
# Last Name:
# Operator: ecoin
# Zone: org
#
# First Name: hylan_john
# Last Name:
# Operator: ecoin
# Zone: hu
#
# First Name: hoffman_darnell
# Last Name:
# Operator: napster
# Zone: org
#
# First Name: sonderling7306
# Last Name:
# Operator: belgaximus
# Zone: gov
#
# First Name: hank
# Last Name:
# Operator: email
# Zone: gov
#
# First Name: johnson_joe
# Last Name:
# Operator: email
# Zone: hu
#
# First Name: lawicki
# Last Name:
# Operator: gaagle
# Zone: tech
#
# First Name: johnson_yates
# Last Name:
# Operator: gaagle
# Zone: gov
#
# First Name: zeller_ty
# Last Name:
# Operator: gaagle
# Zone: me
#
# First Name: thomascasal
# Last Name:
# Operator: imail
# Zone: net
#
# First Name: wagle
# Last Name: dan
# Operator: hotmoille
# Zone: net
#
# First Name: carl3060
# Last Name:
# Operator: proton
# Zone: tech
#
# First Name: roger6892
# Last Name:
# Operator: imail
# Zone: hu
#
# First Name: petervader
# Last Name:
# Operator: ecoin
# Zone: io
#
# First Name: waglehal
# Last Name:
# Operator: belgaximus
# Zone: io
#
# First Name: paulhydinger
# Last Name:
# Operator: proton
# Zone: com
#
# First Name: tapia_john
# Last Name:
# Operator: gaagle
# Zone: xyz
#
# First Name: andersonedward
# Last Name:
# Operator: ecoin
# Zone: xyz
#
# First Name: timsellon
# Last Name:
# Operator: hotmoille
# Zone: com
#
# First Name: tim
# Last Name: fietzer
# Operator: gaagle
# Zone: net
#
# First Name: pakalex
# Last Name:
# Operator: gaagle
# Zone: com
#
# First Name: markpak
# Last Name:
# Operator: proton
# Zone: io
#
# First Name: victordinkins
# Last Name:
# Operator: ecoin
# Zone: org
#
# First Name: kaskel_duffman
# Last Name:
# Operator: imail
# Zone: me
#
# First Name: paul9959
# Last Name:
# Operator: email
# Zone: gov
#
# First Name: ike
# Last Name: maki
# Operator: imail
# Zone: me
#
# First Name: 406392428
# Last Name:
# Operator: belgaximus
# Zone: hu
#
# First Name: ory_nugent
# Last Name:
# Operator: email
# Zone: xyz
#
# First Name: solomangeorge
# Last Name:
# Operator: hotmoille
# Zone: apple
#
# First Name: bateman_weinstein
# Last Name:
# Operator: belgaximus
# Zone: gov
#
# First Name: zeaser
# Last Name:
# Operator: ecoin
# Zone: gov
#
# First Name: ulrichty
# Last Name:
# Operator: odul
# Zone: hu
#
# First Name: alexmcginnis
# Last Name:
# Operator: belgaximus
# Zone: org
#
# First Name: halrice
# Last Name:
# Operator: hotmoille
# Zone: hu
#
# First Name: nelson
# Last Name: steve
# Operator: imail
# Zone: hu
#
# First Name: vail_chapman
# Last Name:
# Operator: youhoo
# Zone: net
#
# First Name: schiebelthomas
# Last Name:
# Operator: ecoin
# Zone: hu
#
# First Name: ike
# Last Name: hancock
# Operator: imail
# Zone: apple
#
# First Name: roger
# Last Name:
# Operator: belgaximus
# Zone: hu
#
# First Name: nugent_fletcher
# Last Name:
# Operator: ecoin
# Zone: hu
#
# First Name: maki8692
# Last Name:
# Operator: imail
# Zone: gov
#
# First Name: adam
# Last Name:
# Operator: email
# Zone: tech
#
# First Name: adam
# Last Name:
# Operator: hotmoille
# Zone: io
#
# First Name: thomasyates
# Last Name:
# Operator: odul
# Zone: com
#
# First Name: celedon_walter
# Last Name:
# Operator: napster
# Zone: hu
#
# First Name: kassing4495
# Last Name:
# Operator: proton
# Zone: io
#
# First Name: boyd_george
# Last Name:
# Operator: odul
# Zone: io
#
# First Name: bowers_ebner
# Last Name:
# Operator: email
# Zone: xyz
#
# First Name: jack9352
# Last Name:
# Operator: odul
# Zone: tech
#
# First Name: lewisdan
# Last Name:
# Operator: youhoo
# Zone: net
#
# First Name: mccormackmark
# Last Name:
# Operator: hotmoille
# Zone: net
#
# First Name: timbauer
# Last Name:
# Operator: odul
# Zone: org
#
# First Name: reamer_rogers
# Last Name:
# Operator: proton
# Zone: hu
#
# First Name: soulisfred
# Last Name:
# Operator: belgaximus
# Zone: gov
#
# First Name: vader
# Last Name: tim
# Operator: hotmoille
# Zone: xyz
#
# First Name: wagnerthomas
# Last Name:
# Operator: youhoo
# Zone: tech
#
# First Name: adamjagtap
# Last Name:
# Operator: hotmoille
# Zone: apple
#
# First Name: paul
# Last Name: reamer
# Operator: napster
# Zone: com
#
# First Name: adam
# Last Name:
# Operator: belgaximus
# Zone: io
#
# First Name: ty
# Last Name:
# Operator: email
# Zone: tech
#
# First Name: edward
# Last Name:
# Operator: email
# Zone: net
#
# First Name: doran2286
# Last Name:
# Operator: imail
# Zone: org
#
# First Name: irwinhal
# Last Name:
# Operator: belgaximus
# Zone: tech
#
# First Name: tyschwager
# Last Name:
# Operator: odul
# Zone: tech
#
# First Name: georgemills
# Last Name:
# Operator: imail
# Zone: apple
#
# First Name: wagle389
# Last Name:
# Operator: odul
# Zone: com
#
# First Name: edwardferro
# Last Name:
# Operator: hotmoille
# Zone: net
#
# First Name: adamostrander
# Last Name:
# Operator: hotmoille
# Zone: gov
#
# First Name: 258546748
# Last Name:
# Operator: imail
# Zone: org
#
# First Name: bencaswell
# Last Name:
# Operator: imail
# Zone: gov
#
# First Name: steve1862
# Last Name:
# Operator: hotmoille
# Zone: com
#
# First Name: halturco
# Last Name:
# Operator: email
# Zone: hu
#
# First Name: tiernan_casal
# Last Name:
# Operator: email
# Zone: com
#
# First Name: alexdoran
# Last Name:
# Operator: napster
# Zone: org
#
# First Name: frick_cannon
# Last Name:
# Operator: gaagle
# Zone: tech
#
# First Name: otto
# Last Name:
# Operator: email
# Zone: apple
#
# First Name: hal
# Last Name:
# Operator: email
# Zone: tech
#
# First Name: ulrich
# Last Name: thomas
# Operator: odul
# Zone: io
#
# First Name: anderson_aaron
# Last Name:
# Operator: odul
# Zone: me
#
# First Name: hoffman_victor
# Last Name:
# Operator: imail
# Zone: tech
#
# First Name: larrythompson
# Last Name:
# Operator: imail
# Zone: apple
#
# First Name: ebnerjohn
# Last Name:
# Operator: gaagle
# Zone: apple
#
# First Name: frank
# Last Name: nelson
# Operator: proton
# Zone: net
#
# First Name: ebner_reamer
# Last Name:
# Operator: email
# Zone: me
#
# First Name: trusela_paul
# Last Name:
# Operator: imail
# Zone: me
#
# First Name: dinkinsalex
# Last Name:
# Operator: email
# Zone: io
#
# First Name: jack3083
# Last Name:
# Operator: belgaximus
# Zone: gov
#
# First Name: casal
# Last Name:
# Operator: youhoo
# Zone: gov
#
# First Name: fred
# Last Name:
# Operator: imail
# Zone: me
#
# First Name: davisgeorge
# Last Name:
# Operator: napster
# Zone: tech
#
# First Name: jagtap
# Last Name:
# Operator: odul
# Zone: com
#
# First Name: fredvalente
# Last Name:
# Operator: gaagle
# Zone: me
#
# First Name: hylan
# Last Name: carl
# Operator: hotmoille
# Zone: gov
#
# First Name: 270804951
# Last Name:
# Operator: napster
# Zone: org
#
# First Name: uddin1875
# Last Name:
# Operator: napster
# Zone: apple
#
# First Name: turco
# Last Name: carl
# Operator: belgaximus
# Zone: tech
#
# First Name: hoffman
# Last Name:
# Operator: gaagle
# Zone: apple
#
# First Name: joe
# Last Name: rogers
# Operator: gaagle
# Zone: xyz
#
# First Name: schmitt_larry
# Last Name:
# Operator: odul
# Zone: gov
#
# First Name: carlsoloman
# Last Name:
# Operator: ecoin
# Zone: com
#
# First Name: nathan6115
# Last Name:
# Operator: imail
# Zone: me
#
# First Name: frank
# Last Name:
# Operator: imail
# Zone: io
#
# First Name: norquist_steve
# Last Name:
# Operator: belgaximus
# Zone: com
#
# First Name: paul
# Last Name:
# Operator: hotmoille
# Zone: gov
#
# First Name: orwig
# Last Name:
# Operator: odul
# Zone: me
#
# First Name: tislerdan
# Last Name:
# Operator: hotmoille
# Zone: tech
#
# First Name: edward6174
# Last Name:
# Operator: imail
# Zone: me
#
# First Name: montepettigrew
# Last Name:
# Operator: hotmoille
# Zone: hu
#
# First Name: schutzlarry
# Last Name:
# Operator: odul
# Zone: net
#
# First Name: zeasertim
# Last Name:
# Operator: proton
# Zone: tech
#
# First Name: walter
# Last Name: kassing
# Operator: odul
# Zone: tech
#
# First Name: ferro
# Last Name: david
# Operator: gaagle
# Zone: tech
#
# First Name: schmitt_schiebel
# Last Name:
# Operator: belgaximus
# Zone: gov
#
# First Name: martin
# Last Name: ben
# Operator: imail
# Zone: me
#
# First Name: benventotla
# Last Name:
# Operator: youhoo
# Zone: org
#
# First Name: ziegler_soloman
# Last Name:
# Operator: imail
# Zone: io
#
# First Name: davidson_rogers
# Last Name:
# Operator: belgaximus
# Zone: xyz
#
# First Name: george
# Last Name:
# Operator: proton
# Zone: org
#
# First Name: ramachandran431
# Last Name:
# Operator: napster
# Zone: hu
#
# First Name: paulostrander
# Last Name:
# Operator: youhoo
# Zone: xyz
#
# First Name: tyseverson
# Last Name:
# Operator: hotmoille
# Zone: hu
#
# First Name: edwardortiz
# Last Name:
# Operator: hotmoille
# Zone: tech
#
# First Name: hal5999
# Last Name:
# Operator: email
# Zone: org
#
# First Name: moody3417
# Last Name:
# Operator: ecoin
# Zone: gov
#
# First Name: trebil_bowers
# Last Name:
# Operator: proton
# Zone: org
#
# First Name: pak9267
# Last Name:
# Operator: ecoin
# Zone: hu
#
# First Name: 883886499
# Last Name:
# Operator: youhoo
# Zone: io
#
# First Name: peterknutson
# Last Name:
# Operator: gaagle
# Zone: hu
#
# First Name: mark
# Last Name:
# Operator: belgaximus
# Zone: gov
#
# First Name: 660694516
# Last Name:
# Operator: napster
# Zone: apple
#
# First Name: larry
# Last Name:
# Operator: belgaximus
# Zone: gov
#
# First Name: ripka1096
# Last Name:
# Operator: email
# Zone: apple
#
# First Name: bowers
# Last Name: otto
# Operator: proton
# Zone: gov
#
# First Name: ulrich_fred
# Last Name:
# Operator: imail
# Zone: tech
#
# First Name: dugelman_carl
# Last Name:
# Operator: youhoo
# Zone: io
#
# First Name: 801140752
# Last Name:
# Operator: email
# Zone: net
#
# First Name: jurgenson
# Last Name: aaron
# Operator: napster
# Zone: io
#
# First Name: stahl_ty
# Last Name:
# Operator: gaagle
# Zone: tech
#
# First Name: lawickimatthew
# Last Name:
# Operator: gaagle
# Zone: tech
#
# First Name: halbongard
# Last Name:
# Operator: hotmoille
# Zone: tech
#
# First Name: soukup
# Last Name: roger
# Operator: youhoo
# Zone: com
#
# First Name: jack
# Last Name: sweeney
# Operator: hotmoille
# Zone: org

# %% [markdown]
# **12. Another way of doing things.**

# %%
# Extract the first name, last name, operator, and zone from an email 

mail = "audrey.boulevart@benextcomapgny.com"

# splitMail: a list that results from processing the email address mail. 
# replaces periods (".") in the email address with spaces and then 
# splits the email address into two parts using the "@" symbol as the delimiter. 
# copy(): contain the first part (before "@") and the second part (after "@").

splitMail = mail.replace(".", " ").split("@").copy()

firstName = []
name = []
ope = []
zone = []

firstName.append(splitMail[0].split()[0])
name.append(splitMail[0].split()[-1])
ope.append(splitMail[1].split()[0])
zone.append(splitMail[1].split()[-1])

print(splitMail)
print(splitMail[0].split()[0])
print(splitMail[0].split()[-1])
print(splitMail[1].split()[0])
print((splitMail[1].split()[-1]))
firstName, name, ope, zone
# Out:
# ['audrey boulevart', 'benextcomapgny com']
# audrey
# boulevart
# benextcomapgny
# com
# (['audrey'], ['boulevart'], ['benextcomapgny'], ['com'])

# %% [markdown]
# Repeat the previous exercise with this new formula and compare the length of your lists with those of the previous exercise.
# What do you notice ?
